# %%
# Load dependencies
import os
import pandas as pd
import numpy as np
from IPython.display import display

# %%
"""
Desc: Calculate the grouped average
Input: df (pandas DataFrame), 
       gbCols (list of column names to groupby),
       avgCols (list of column names to average),
       sortCols (list of column names to sort by),
       asc (boolean) - ascending or descending sort
Output: x (pandas DataFrame) - (sorted) dataframe with averages of specified columns
"""
def df_gb_avg(df, gbCols, avgCols, sortCols, asc=False):
    
    x = pd.DataFrame(df.groupby(gbCols)[avgCols].mean())
    
    x = x.sort_values(by=sortCols, ascending=asc)
    
    display(x)
    
    return x


"""
Desc: Calculate the grouped sum
Input: df (pandas DataFrame), 
       gbCols (list of column names to groupby),
       avgCols (list of column names to average),
       sortCols (list of column names to sort by),
       asc (boolean) - ascending or descending sort
Output: x (pandas DataFrame) - (sorted) dataframe with averages of specified columns
"""
def df_gb_sum(df, gbCols, avgCols, sortCols, asc=False):
    
    x = pd.DataFrame(df.groupby(gbCols)[avgCols].sum())
    
    x = x.sort_values(by=sortCols, ascending=asc)
    
    display(x)
    
    return x


"""
Desc: Count the number of times a value changes
Input: x (pandas Series)
Output: Total number of times a value changed in the Series
"""
def numChanges(x):
    return sum(x.iloc[:-1] != x.shift(-1).iloc[:-1])

# %%
# Load data
incidents = pd.read_csv("INCIDENTS.csv", low_memory=False)
incOwnHist = pd.read_csv("INCIDENT_OWNER_HISTORY.csv", low_memory=False)

# Display
display(incidents.head())

# Print length
print(len(incidents))

# Display
display(incOwnHist.head())

# Print length
print(len(incOwnHist.index))
# Out:
#   TICKET_NMBR              PARENT_SERVICE                     service  org_id  \
# 0  IN10028612                  Middleware                  Middleware  1342.0
# 1  IN10028613                    Midrange     Midrange - Windows -X86  1342.0
# 2  IN10028614                   Mainframe                   Mainframe  1065.0
# 3  IN10028615  High-performance Computing  High-performance Computing  1342.0
# 4  IN10028616                         NaN                          -1  1342.0
#
#   ASSIGNED_GROUP           OPEN_DATE          CLOSE_DATE PRIORITY  STATUS  \
# 0       DC000152  01APR2016:00:01:16  01APR2016:08:26:30      Low  CLOSED
# 1       NDS00032  01APR2016:00:35:21  11APR2016:11:06:12      Low  CLOSED
# 2       DC000155  01APR2016:01:43:26  01APR2016:10:28:51      Low  CLOSED
# 3       DC000133  01APR2016:02:57:00  01APR2016:07:42:08      Low  CLOSED
# 4            NaN  01APR2016:05:21:02  01APR2016:05:23:39      Low  CLOSED
#
#    ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS  AGING CLASS_STRUCTURE_ID  \
# 0                   8.42                     1.43    NaN               2101
# 1                 250.51                    64.10    NaN                 21
# 2                   8.76                     3.47    NaN               3102
# 3                   4.75                     0.70    NaN               3102
# 4                   0.04                     0.00    NaN               2103
#
#                  class_structure CLASSIFICATION_ID    classification  \
# 0            IT Issue \ Hardware              2101    Hardware Issue
# 1                       IT Issue                21          IT Issue
# 2  IT Request \ Software Request              3102  Software Request
# 3  IT Request \ Software Request              3102  Software Request
# 4            IT Issue \ Networks              2103    Networks Issue
#
#    EXTERNAL_SYSTEM  GLOBAL_TICKET_ID CLOSURE_CODE  LAST_MODIFIED_DATE
# 0  EVENTMANAGEMENT               NaN          OTH  12APR2016:05:30:11
# 1  EVENTMANAGEMENT               NaN          CIS  22APR2016:05:30:33
# 2    CREATEDFROMSR               NaN          SUP  12APR2016:05:30:09
# 3  EVENTMANAGEMENT               NaN          OSD  12APR2016:05:30:10
# 4        PHONECALL               NaN          AUT  11APR2016:05:30:07
# 226296
#   ticket_nmbr    STATUS assigned_group PARENT_SERVICE  \
# 0  IN10028612    QUEUED       DC000152     Middleware
# 1  IN10028612  RESOLVED       DC000152     Middleware
# 2  IN10028612    CLOSED       DC000152     Middleware
# 3  IN10028613    QUEUED       NDS00032       Midrange
# 4  IN10028613  RESOLVED       NDS00032       Midrange
#
#                    service         CHANGE_DATE  TIME_IN_STATUS_BY_OWNER_HRS
# 0               Middleware  01APR2016:00:03:12                     8.383333
# 1               Middleware  01APR2016:08:26:30                     0.000000
# 2               Middleware  12APR2016:05:30:11                          NaN
# 3  Midrange - Windows -X86  01APR2016:01:04:45                    64.100000
# 4  Midrange - Windows -X86  11APR2016:11:06:12                     0.000000
# 1152409

# %%
# Drop NaNs in incOwnHist
df = incOwnHist[incOwnHist["TIME_IN_STATUS_BY_OWNER_HRS"].notna()]

# Get number of reassignments
ra = pd.DataFrame(df.groupby(["ticket_nmbr"], as_index=False).agg({'STATUS': lambda x: list(dict.fromkeys(x)),
                                                                   'PARENT_SERVICE': lambda x: list(dict.fromkeys(x)),
                                                                   'service': lambda x: list(dict.fromkeys(x)),
                                                                   'TIME_IN_STATUS_BY_OWNER_HRS' : 'sum',
                                                                   'assigned_group' : numChanges
                                                                 }))

# Rename columns
ra.columns = ["TICKET_NMBR", "STATUSES", "PARENT_SERVICES", "services","TIME_IN_STATUS_BY_OWNER_HRS", "reassign_num"]

# Get number of reassignments
df2 = pd.DataFrame(df.groupby(["ticket_nmbr"], as_index=False).agg({'assigned_group' : lambda x: list(dict.fromkeys(x))}))

# Rename columns
df2.columns = ["TICKET_NMBR", "assigned_groups"]

# Merge ra with df2
df = ra.merge(df2)

# Display
display(df.head())
# Out:
#   TICKET_NMBR                    STATUSES               PARENT_SERVICES  \
# 0  IN10028612          [QUEUED, RESOLVED]                  [Middleware]
# 1  IN10028613          [QUEUED, RESOLVED]                    [Midrange]
# 2  IN10028614  [QUEUED, INPROG, RESOLVED]                   [Mainframe]
# 3  IN10028615  [QUEUED, INPROG, RESOLVED]  [High-performance Computing]
# 4  IN10028617          [QUEUED, RESOLVED]                    [Midrange]
#
#                        services  TIME_IN_STATUS_BY_OWNER_HRS  reassign_num  \
# 0                  [Middleware]                     8.383333             0
# 1     [Midrange - Windows -X86]                    64.100000             0
# 2                   [Mainframe]                     8.750000             0
# 3  [High-performance Computing]                     3.616667             0
# 4     [Midrange - Windows -X86]                   116.150000             0
#
#   assigned_groups
# 0      [DC000152]
# 1      [NDS00032]
# 2      [DC000155]
# 3      [DC000133]
# 4      [DC000115]

# %%
# Add columns to count number of status, parent_services, service, and assigned groups
df["num_status"] = df["STATUSES"].str.len()
df["num_PS"] = df["PARENT_SERVICES"].str.len()
df["num_service"] = df["services"].str.len()
df["num_AG"] = df["assigned_groups"].str.len()

# Merge df with incidents
df = incidents.merge(df)

# Display
display(df)
# Out:
#        TICKET_NMBR              PARENT_SERVICE                     service  \
# 0       IN10028612                  Middleware                  Middleware
# 1       IN10028613                    Midrange     Midrange - Windows -X86
# 2       IN10028614                   Mainframe                   Mainframe
# 3       IN10028615  High-performance Computing  High-performance Computing
# 4       IN10028617                    Midrange     Midrange - Windows -X86
# ...            ...                         ...                         ...
# 224413  IN10293549          Directory Services          Directory Services
# 224414  IN10293550                     Storage              Storage - File
# 224415  IN10293551                  Middleware                  Middleware
# 224416  IN10293552                   Mainframe                   Mainframe
# 224417  IN10293554                    Midrange                    Midrange
#
#         org_id ASSIGNED_GROUP           OPEN_DATE          CLOSE_DATE  \
# 0       1342.0       DC000152  01APR2016:00:01:16  01APR2016:08:26:30
# 1       1342.0       NDS00032  01APR2016:00:35:21  11APR2016:11:06:12
# 2       1065.0       DC000155  01APR2016:01:43:26  01APR2016:10:28:51
# 3       1342.0       DC000133  01APR2016:02:57:00  01APR2016:07:42:08
# 4       1342.0       DC000115  01APR2016:06:21:10  18APR2016:13:09:13
# ...        ...            ...                 ...                 ...
# 224413  1213.0       ITS00379  30NOV2021:23:19:38  01DEC2021:07:51:00
# 224414  1042.0       DC000263  30NOV2021:23:19:43  01DEC2021:12:09:08
# 224415  1047.0       DC000152  30NOV2021:23:39:31  01DEC2021:05:46:49
# 224416  1047.0       DC000155  30NOV2021:23:38:56  01DEC2021:03:10:13
# 224417  1047.0       DC000188  30NOV2021:23:49:09  01DEC2021:10:24:14
#
#        PRIORITY  STATUS  ACTUAL_COMPLETION_HRS  ...  \
# 0           Low  CLOSED                   8.42  ...
# 1           Low  CLOSED                 250.51  ...
# 2           Low  CLOSED                   8.76  ...
# 3           Low  CLOSED                   4.75  ...
# 4        Medium  CLOSED                 414.80  ...
# ...         ...     ...                    ...  ...
# 224413      Low  CLOSED                   8.52  ...
# 224414      Low  CLOSED                  12.82  ...
# 224415      Low  CLOSED                   6.12  ...
# 224416   Medium  CLOSED                   3.52  ...
# 224417      Low  CLOSED                  10.58  ...
#
#                           STATUSES                         PARENT_SERVICES  \
# 0               [QUEUED, RESOLVED]                            [Middleware]
# 1               [QUEUED, RESOLVED]                              [Midrange]
# 2       [QUEUED, INPROG, RESOLVED]                             [Mainframe]
# 3       [QUEUED, INPROG, RESOLVED]            [High-performance Computing]
# 4               [QUEUED, RESOLVED]                              [Midrange]
# ...                            ...                                     ...
# 224413          [QUEUED, RESOLVED]  [Other Activities, Directory Services]
# 224414          [INPROG, RESOLVED]                               [Storage]
# 224415                  [RESOLVED]                            [Middleware]
# 224416          [INPROG, RESOLVED]           [Other Activities, Mainframe]
# 224417                  [RESOLVED]                              [Midrange]
#
#                                                 services  \
# 0                                           [Middleware]
# 1                              [Midrange - Windows -X86]
# 2                                            [Mainframe]
# 3                           [High-performance Computing]
# 4                              [Midrange - Windows -X86]
# ...                                                  ...
# 224413  [Other - Service Management, Directory Services]
# 224414                                  [Storage - File]
# 224415                                      [Middleware]
# 224416           [Other - Service Management, Mainframe]
# 224417                                        [Midrange]
#
#        TIME_IN_STATUS_BY_OWNER_HRS reassign_num       assigned_groups  \
# 0                         8.383333            0            [DC000152]
# 1                        64.100000            0            [NDS00032]
# 2                         8.750000            0            [DC000155]
# 3                         3.616667            0            [DC000133]
# 4                       116.150000            0            [DC000115]
# ...                            ...          ...                   ...
# 224413                    0.000000            1  [ESI00011, ITS00379]
# 224414                    0.000000            0            [DC000263]
# 224415                    0.000000            0            [DC000152]
# 224416                    0.000000            1  [SM000562, DC000155]
# 224417                    0.000000            0            [DC000188]
#
#        num_status  num_PS num_service num_AG
# 0               2       1           1      1
# 1               2       1           1      1
# 2               3       1           1      1
# 3               3       1           1      1
# 4               2       1           1      1
# ...           ...     ...         ...    ...
# 224413          2       2           2      2
# 224414          2       1           1      1
# 224415          1       1           1      1
# 224416          2       2           2      2
# 224417          1       1           1      1
#
# [224418 rows x 30 columns]

# %%
# Save to csv
df.to_csv("merged_ssc_ticket_data.csv")

# %%
# Create folders if they do not already exist
if not os.path.exists("./AVGDATA/"):
    os.mkdir("./AVGDATA/")

if not os.path.exists("./AVGDATA_JEM/"):
    os.mkdir("./AVGDATA_JEM/")
    
if not os.path.exists("./AVGDATA_EEM/"):
    os.mkdir("./AVGDATA_EEM/")

if not os.path.exists("./RA_DATA/"):
    os.mkdir("./RA_DATA/")

# %%
# Print how many tickets been reassigned
print("Total number of tickets that have reassigned at least once:", len(df[df["reassign_num"] > 0].index))
print("Percentage of tickets that have been reassigned at least once:", 
      len(df[df["reassign_num"] > 0].index)/len(df.index))
print("Total number of tickets that have not been reassigned:", len(df[df["reassign_num"] == 0].index))
print("Percentage of tickets that have been reassigned at least once:", 
      1 - len(df[df["reassign_num"] > 0].index)/len(df.index))

# Group by different conditions
"""Average number of reassignment"""
df_stat = df_gb_avg(df, ["STATUS"], ["reassign_num"], ["reassign_num"])
df_pr = df_gb_avg(df, ["PRIORITY"], ["reassign_num"], ["reassign_num"])
df_PS = df_gb_avg(df, ["PARENT_SERVICE"], ["reassign_num"], ["reassign_num"])
df_serv = df_gb_avg(df, ["service"], ["reassign_num"], ["reassign_num"])
df_oid = df_gb_avg(df, ["org_id"], ["reassign_num"], ["reassign_num"])
df_AG = df_gb_avg(df, ["ASSIGNED_GROUP"], ["reassign_num"], ["reassign_num"])

"""Avg number of reassignment by Priority"""
df_pr_stat = df_gb_avg(df, ["PRIORITY", "STATUS"], ["reassign_num"], ["reassign_num"])
df_pr_PS = df_gb_avg(df, ["PRIORITY", "PARENT_SERVICE"], ["reassign_num"], ["reassign_num"])
df_pr_serv = df_gb_avg(df, ["PRIORITY", "service"], ["reassign_num"], ["reassign_num"])
df_pr_oid = df_gb_avg(df, ["PRIORITY", "org_id"], ["reassign_num"], ["reassign_num"])
df_pr_AG = df_gb_avg(df, ["PRIORITY", "ASSIGNED_GROUP"], ["reassign_num"], ["reassign_num"])

# Save to csv
df_stat.to_csv("./RA_DATA/df_stat_avg.csv")
df_pr.to_csv("./RA_DATA/df_pr_avg.csv")
df_PS.to_csv("./RA_DATA/df_PS_avg.csv")
df_serv.to_csv("./RA_DATA/df_serv_avg.csv")
df_oid.to_csv("./RA_DATA/df_oid_avg.csv")
df_AG.to_csv("./RA_DATA/df_AG_avg.csv")

df_pr_stat.to_csv("./RA_DATA/df_stat_avg.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_avg.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_avg.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_avg.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_avg.csv")
# Out:
# Total number of tickets that have reassigned at least once: 58094
# Percentage of tickets that have been reassigned at least once: 0.2588651534190662
# Total number of tickets that have not been reassigned: 166324
# Percentage of tickets that have been reassigned at least once: 0.7411348465809338
#           reassign_num
# STATUS
# AWAITCHG      1.400000
# AWAITCUS      1.000000
# SLAHOLD       0.942857
# QUEUED        0.844828
# INPROG        0.590909
# CLOSED        0.435960
# RESOLVED      0.410256
# AWAITVEN      0.285714
#           reassign_num
# PRIORITY
# High          0.791935
# Medium        0.542302
# Low           0.385898
#                                                reassign_num
# PARENT_SERVICE
# IT Continuity Support Service                      3.000000
# WTD Provisioning                                   2.166667
# Solutions Integration Service (SIS)                2.000000
# Internal Credential Management (ICM)               1.271959
# Satellite                                          1.190476
# Internet                                           1.000000
# Other Activities                                   0.855451
# Directory Services                                 0.783923
# Cloud Brokering                                    0.775194
# Toll-free Voice                                    0.761905
# Government of Canada Managed Security Service      0.724382
# Classified Infrastructure                          0.636364
# Firewall                                           0.636047
# Managed Secure File Transfer                       0.625000
# Database                                           0.607895
# Intra-building Network Services                    0.572497
# Storage                                            0.467167
# Data Centre Facilities Management                  0.461130
# Email                                              0.447826
# Secure Remote Access                               0.412210
# Mobile Devices                                     0.391818
# Mainframe                                          0.391087
# GC WAN                                             0.385557
# Fixed Line                                         0.381316
# Middleware                                         0.369078
# Conferencing Services                              0.325672
# Distributed Print                                  0.281513
# Midrange                                           0.274866
# Contact Centre                                     0.228697
# Workplace Technology Services                      0.165966
# High-performance Computing                         0.137590
# Facilities-as-a-service (FaaS)                     0.000000
# Bulk Print                                         0.000000
#                                                     reassign_num
# service
# IT Continuity Support Service                           3.000000
# WTD - Hardware                                          2.166667
# To be determined                                        2.000000
# Solutions Integration Service (SIS)                     2.000000
# Fixed - Calling Card                                    2.000000
# ...                                                          ...
# High-performance Computing                              0.141088
# HPC -Big Data Exchange                                  0.102617
# Service Management - Enterprise Control Center ...      0.000000
# Bulk Print                                              0.000000
# Faciltiies-as-a-service (FaaS)                          0.000000
#
# [66 rows x 1 columns]
#         reassign_num
# org_id
# 918.0       6.000000
# 867.0       3.000000
# 1232.0      3.000000
# 1182.0      2.000000
# 948.0       2.000000
# ...              ...
# 1342.0      0.346161
# 1062.0      0.246055
# 1355.0      0.232734
# 988.0       0.000000
# 1205.0      0.000000
#
# [70 rows x 1 columns]
#                 reassign_num
# ASSIGNED_GROUP
# ESI00019                 5.0
# NW000422                 5.0
# ITS00350                 4.0
# ESI00042                 4.0
# SDATIER1                 4.0
# ...                      ...
# ITS00387                 0.0
# NDS00026                 0.0
# NDS00031                 0.0
# DC000105                 0.0
# TIVMON                   0.0
#
# [450 rows x 1 columns]
#                    reassign_num
# PRIORITY STATUS
# High     AWAITCUS      5.000000
#          INPROG        2.000000
# Low      AWAITCHG      1.750000
# Medium   SLAHOLD       1.187500
#          QUEUED        1.034483
#          AWAITCUS      0.913043
#          RESOLVED      0.900000
#          INPROG        0.846154
# High     CLOSED        0.790594
# Low      SLAHOLD       0.736842
#          AWAITCUS      0.714286
#          QUEUED        0.655172
# Medium   AWAITVEN      0.545455
#          CLOSED        0.541586
# Low      CLOSED        0.385827
#          INPROG        0.384615
#          RESOLVED      0.241379
#          AWAITVEN      0.210526
# Medium   AWAITCHG      0.000000
#                                               reassign_num
# PRIORITY PARENT_SERVICE
# High     Cloud Brokering                          8.000000
# Medium   IT Continuity Support Service            3.000000
# High     Mainframe                                2.428571
# Low      WTD Provisioning                         2.166667
#          Solutions Integration Service (SIS)      2.000000
# ...                                                    ...
# Medium   Facilities-as-a-service (FaaS)           0.000000
#          Bulk Print                               0.000000
# Low      Bulk Print                               0.000000
# High     Distributed Print                        0.000000
#          Classified Infrastructure                0.000000
#
# [85 rows x 1 columns]
#                                                              reassign_num
# PRIORITY service
# High     Cloud Brokering                                         8.000000
#          -1                                                      3.000000
# Medium   IT Continuity Support Service                           3.000000
# High     Mainframe                                               2.666667
# Low      WTD - Hardware                                          2.166667
# ...                                                                   ...
#          Service Management - Enterprise Control Center ...      0.000000
# Medium   Bulk Print                                              0.000000
#          Faciltiies-as-a-service (FaaS)                          0.000000
#          Fixed - Key Systems and Interchange                     0.000000
# High     Classified Infrastructure - GCSI - Hosting Envi...      0.000000
#
# [170 rows x 1 columns]
#                   reassign_num
# PRIORITY org_id
# Low      918.0            11.0
# High     1068.0            4.5
# Medium   1232.0            3.0
#          867.0             3.0
# High     17498.0           3.0
# ...                        ...
#          1165.0            0.0
#          1202.0            0.0
#          1732.0            0.0
#          1247.0            0.0
#          1243.0            0.0
#
# [181 rows x 1 columns]
#                          reassign_num
# PRIORITY ASSIGNED_GROUP
# High     ITS00347                10.0
#          DC000245                10.0
#          DC000121                 8.0
# Medium   ITS00350                 8.0
#          COR00559                 5.0
# ...                               ...
#          ITS00387                 0.0
# Low      ITS00350                 0.0
#          ITS00371                 0.0
#          ITS00390                 0.0
# Medium   TIVMON                   0.0
#
# [990 rows x 1 columns]

# %%
"""Sum reassignment number"""
df_stat = df_gb_sum(df, ["STATUS"], ["reassign_num"], ["reassign_num"])
df_pr = df_gb_sum(df, ["PRIORITY"], ["reassign_num"], ["reassign_num"])
df_PS = df_gb_sum(df, ["PARENT_SERVICE"], ["reassign_num"], ["reassign_num"])
df_serv = df_gb_sum(df, ["service"], ["reassign_num"], ["reassign_num"])
df_oid = df_gb_sum(df, ["org_id"], ["reassign_num"], ["reassign_num"])
df_AG = df_gb_sum(df, ["ASSIGNED_GROUP"], ["reassign_num"], ["reassign_num"])

"""Sum reassignment number by Priority"""
df_pr_stat = df_gb_sum(df, ["PRIORITY", "STATUS"], ["reassign_num"], ["reassign_num"])
df_pr_PS = df_gb_sum(df, ["PRIORITY", "PARENT_SERVICE"], ["reassign_num"], ["reassign_num"])
df_pr_serv = df_gb_sum(df, ["PRIORITY", "service"], ["reassign_num"], ["reassign_num"])
df_pr_oid = df_gb_sum(df, ["PRIORITY", "org_id"], ["reassign_num"], ["reassign_num"])
df_pr_AG = df_gb_sum(df, ["PRIORITY", "ASSIGNED_GROUP"], ["reassign_num"], ["reassign_num"])

# Save to csv
df_stat.to_csv("./RA_DATA/df_stat_sum.csv")
df_pr.to_csv("./RA_DATA/df_pr_sum.csv")
df_PS.to_csv("./RA_DATA/df_PS_sum.csv")
df_serv.to_csv("./RA_DATA/df_serv_sum.csv")
df_oid.to_csv("./RA_DATA/df_oid_sum.csv")
df_AG.to_csv("./RA_DATA/df_AG_sum.csv")

df_pr_stat.to_csv("./RA_DATA/df_stat_sum.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_sum.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_sum.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_sum.csv")
df_pr_stat.to_csv("./RA_DATA/df_stat_sum.csv")
# Out:
#           reassign_num
# STATUS
# CLOSED           97714
# QUEUED              49
# INPROG              39
# SLAHOLD             33
# AWAITCUS            31
# RESOLVED            16
# AWAITVEN            14
# AWAITCHG             7
#           reassign_num
# PRIORITY
# Low              61210
# Medium           33492
# High              3201
#                                                reassign_num
# PARENT_SERVICE
# Other Activities                                      25939
# Midrange                                              12043
# Intra-building Network Services                       11636
# GC WAN                                                10139
# Middleware                                             5617
# Mobile Devices                                         4147
# Fixed Line                                             3796
# Directory Services                                     3345
# Firewall                                               3109
# High-performance Computing                             3086
# Storage                                                2554
# Email                                                  2472
# Mainframe                                              2036
# Data Centre Facilities Management                      1999
# Secure Remote Access                                   1580
# Contact Centre                                         1350
# Conferencing Services                                  1006
# Internal Credential Management (ICM)                    753
# Database                                                462
# Government of Canada Managed Security Service           205
# Toll-free Voice                                         176
# Cloud Brokering                                         100
# Workplace Technology Services                            79
# Distributed Print                                        67
# Satellite                                                50
# Managed Secure File Transfer                             45
# Classified Infrastructure                                28
# WTD Provisioning                                         13
# IT Continuity Support Service                             3
# Solutions Integration Service (SIS)                       2
# Internet                                                  1
# Facilities-as-a-service (FaaS)                            0
# Bulk Print                                                0
#                                                     reassign_num
# service
# Other - Service Management                                 21022
# GC WAN                                                      9790
# IBN - GC LAN                                                7398
# Midrange - Windows -X86                                     6742
# Middleware                                                  5617
# ...                                                          ...
# IBN - Cabling                                                  1
# Internet                                                       1
# Bulk Print                                                     0
# Faciltiies-as-a-service (FaaS)                                 0
# Service Management - Enterprise Control Center ...             0
#
# [66 rows x 1 columns]
#         reassign_num
# org_id
# 1342.0         25889
# 1047.0         12756
# 1028.0          6914
# 1062.0          6595
# 1045.0          5079
# ...              ...
# 837.0              1
# 1183.0             1
# 1233.0             1
# 988.0              0
# 1205.0             0
#
# [70 rows x 1 columns]
#                 reassign_num
# ASSIGNED_GROUP
# ESI00011               16951
# NW000417                4304
# DC000152                4021
# NW000405                2257
# NW000459                2226
# ...                      ...
# EDC00083                   0
# NW000520                   0
# EDC00056                   0
# EDC00052                   0
# TIVMON                     0
#
# [450 rows x 1 columns]
#                    reassign_num
# PRIORITY STATUS
# Low      CLOSED           61135
# Medium   CLOSED           33385
# High     CLOSED            3194
# Medium   QUEUED              30
#          INPROG              22
#          AWAITCUS            21
#          SLAHOLD             19
# Low      QUEUED              19
#          INPROG              15
#          SLAHOLD             14
# Medium   RESOLVED             9
# Low      AWAITVEN             8
#          RESOLVED             7
#          AWAITCHG             7
# Medium   AWAITVEN             6
# Low      AWAITCUS             5
# High     AWAITCUS             5
#          INPROG               2
# Medium   AWAITCHG             0
#                                           reassign_num
# PRIORITY PARENT_SERVICE
# Low      Other Activities                        17979
#          Midrange                                 8031
# Medium   Other Activities                         7342
# Low      Intra-building Network Services          6440
# Medium   GC WAN                                   5180
# ...                                                ...
# High     Distributed Print                           0
# Low      Bulk Print                                  0
# Medium   Bulk Print                                  0
#          Facilities-as-a-service (FaaS)              0
# High     Classified Infrastructure                   0
#
# [85 rows x 1 columns]
#                                                              reassign_num
# PRIORITY service
# Low      Other - Service Management                                 14636
# Medium   Other - Service Management                                  5946
#          GC WAN                                                      4934
# Low      GC WAN                                                      4571
#          Midrange - Windows -X86                                     4213
# ...                                                                   ...
# High     Distributed Print                                              0
# Low      Service Management - Enterprise Control Center ...             0
#          Bulk Print                                                     0
# Medium   Bulk Print                                                     0
# High     GC WAN International                                           0
#
# [170 rows x 1 columns]
#                  reassign_num
# PRIORITY org_id
# Low      1342.0         16441
# Medium   1342.0          8769
# Low      1047.0          7638
#          1028.0          5626
#          1062.0          4761
# ...                       ...
# Medium   1337.0             0
#          988.0              0
# High     1247.0             0
#          1243.0             0
#          1202.0             0
#
# [181 rows x 1 columns]
#                          reassign_num
# PRIORITY ASSIGNED_GROUP
# Low      ESI00011               12036
# Medium   ESI00011                4619
#          NW000417                2408
# Low      DC000152                2290
#          NW000417                1838
# ...                               ...
#          ESI00046                   0
#          EU000204                   0
#          ITS00109                   0
#          ITS00315                   0
# Medium   TIVMON                     0
#
# [990 rows x 1 columns]

# %% [markdown]
# # Incidents Owner History Data

# %%
# Average time incidents spend in particular status
avgTimeStatus = df_gb_avg(incOwnHist, ['STATUS'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeStatus.to_csv("./AVGDATA/IOH_avgTimeStatus.csv")

# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(incOwnHist, ['assigned_group'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA/IOH_avgTimeAG.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(incOwnHist, ['PARENT_SERVICE'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA/IOH_avgTimePS.csv")

# Average time incidents spend by service
avgTimeServ = df_gb_avg(incOwnHist, ['service'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeServ.to_csv("./AVGDATA/IOH_avgTimeServ.csv")
# Out:
#             TIME_IN_STATUS_BY_OWNER_HRS
# STATUS
# PENDINGREV                   209.543013
# PENDINGCHG                   158.836006
# AWAITVEN                     144.054339
# SLAHOLD                      128.120452
# AWAITCHG                     127.377065
# PENDINGVEN                   102.631822
# PENDINGCUS                    92.318825
# AWAITCUS                      85.690441
# PENDING                       68.230397
# QUEUED                        47.523962
# INPROG                        40.150039
# HISTEDIT                      16.639815
# NEW                            8.283333
# RESOLVED                       0.147288
# CLOSED                              NaN
#                 TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group
# ITS00386                        2128.316667
# SM000541                        1973.583333
# EDC00080                        1771.750000
# NW000468                        1766.233333
# NSD00012                        1639.316667
# ...                                     ...
# DC000265                                NaN
# ITS00400                                NaN
# NW000501                                NaN
# PM000620                                NaN
# SM000583                                NaN
#
# [587 rows x 1 columns]
#                                                TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE
# IT Continuity Support Service                                  1973.583333
# Bulk Print                                                      377.007738
# Solutions Integration Service (SIS)                             303.705000
# WTD Provisioning                                                175.387931
# Satellite                                                       135.465563
# Intra-building Network Services                                  69.585276
# Data Centre Facilities Management                                68.552445
# Cloud Brokering                                                  63.118243
# Firewall                                                         61.067085
# Toll-free Voice                                                  55.636462
# Secure Remote Access                                             51.493357
# Distributed Print                                                50.740799
# Classified Infrastructure                                        46.976953
# Fixed Line                                                       45.723753
# Government of Canada Managed Security Service                    45.552475
# Contact Centre                                                   45.062572
# Conferencing Services                                            43.938437
# Other Activities                                                 43.391817
# Storage                                                          38.900843
# Email                                                            38.376691
# Database                                                         36.900550
# Directory Services                                               33.298446
# High-performance Computing                                       30.110752
# GC WAN                                                           29.611648
# Internal Credential Management (ICM)                             28.351616
# Mobile Devices                                                   23.581246
# Midrange                                                         23.473131
# Mainframe                                                        18.260883
# Middleware                                                       16.563617
# Workplace Technology Services                                    14.495464
# Managed Secure File Transfer                                     13.037097
#                                      TIME_IN_STATUS_BY_OWNER_HRS
# service
# IT Continuity Support Service                        1973.583333
# WTD Provisioning                                      625.816667
# Solutions Integration Service (SIS)                   428.064286
# Bulk Print                                            377.007738
# IBN - Cabling                                         346.957143
# ...                                                          ...
# Managed Secure File Transfer                           13.037097
# Mobile - Voice & Data                                  12.936081
# Mainframe                                              12.075492
# Fixed - Centrex                                         9.989080
# HPC - Interaction & Visualization                       9.812861
#
# [65 rows x 1 columns]

# %%
"""Group By Status"""
# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(incOwnHist, ['assigned_group', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA/IOH_avgTimeAGStatus.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(incOwnHist, ['PARENT_SERVICE', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA/IOH_avgTimePSStatus.csv")

# Average time incidents spend by service
avgTimeServ = df_gb_avg(incOwnHist, ['service', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeServ.to_csv("./AVGDATA/IOH_avgTimeServStatus.csv")
# Out:
#                          TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group STATUS
# ESI00052       AWAITCUS                  5550.833333
# SM000541       INPROG                    3855.800000
# NW000468       INPROG                    3530.733333
# ITS00302       INPROG                    3306.866667
# SM000575       INPROG                    2972.000000
# ...                                              ...
# SM000582       CLOSED                            NaN
# SM000583       QUEUED                            NaN
# SM000585       CLOSED                            NaN
# SM000586       CLOSED                            NaN
# TIVMON         CLOSED                            NaN
#
# [3585 rows x 1 columns]
#                                                 TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE                      STATUS
# IT Continuity Support Service       INPROG                      3855.800000
# Middleware                          PENDINGCHG                  1504.883333
# Database                            PENDINGCHG                  1503.183333
# Mobile Devices                      PENDINGCHG                  1173.000000
# Toll-free Voice                     PENDING                      931.566667
# ...                                                                     ...
# Solutions Integration Service (SIS) CLOSED                              NaN
# Storage                             CLOSED                              NaN
# Toll-free Voice                     CLOSED                              NaN
# WTD Provisioning                    CLOSED                              NaN
# Workplace Technology Services       CLOSED                              NaN
#
# [353 rows x 1 columns]
#                                                   TIME_IN_STATUS_BY_OWNER_HRS
# service                               STATUS
# IT Continuity Support Service         INPROG                      3855.800000
# Other - Project Management & Delivery AWAITCHG                    1743.341667
# Middleware                            PENDINGCHG                  1504.883333
# Database                              PENDINGCHG                  1503.183333
# Solutions Integration Service (SIS)   INPROG                      1485.216667
# ...                                                                       ...
# Storage - File                        CLOSED                              NaN
# To be determined                      CLOSED                              NaN
# Toll-free Voice                       CLOSED                              NaN
# WTD - Hardware                        CLOSED                              NaN
# Workplace Technology Services         CLOSED                              NaN
#
# [688 rows x 1 columns]

# %% [markdown]
# # Incident Data

# %%
# Average completion time by status
avgCmplStatus = df_gb_avg(incidents, ['STATUS'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA/Inc_avgCmplStatus.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(incidents, ['PARENT_SERVICE'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA/Inc_avgCmplPS.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(incidents, ['service'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA/Inc_avgCmplServ.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(incidents, ['ASSIGNED_GROUP'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA/Inc_avgCmplAG.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(incidents, ['org_id'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(incidents, ['org_id'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA/Inc_avgCmplORG.csv")
avgBizORG.to_csv("./AVGDATA/Inc_avgBizORG.csv")
# Out:
#           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS
# RESOLVED            1926.444107               553.146786
# INPROG              1791.134000               508.100000
# CLOSED               263.471013                80.581383
# SLAHOLD               98.186667                28.856667
# QUEUED                16.035000                 9.025000
# AWAITVEN               1.590833                 0.238333
# AWAITCHG                    NaN                      NaN
# AWAITCUS                    NaN                      NaN
#                                                ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE
# IT Continuity Support Service                           14735.130000
# Solutions Integration Service (SIS)                      4071.950000
# Satellite                                                1750.180732
# Bulk Print                                                947.716667
# Firewall                                                  490.807570
# Toll-free Voice                                           482.581790
# Contact Centre                                            454.087896
# Intra-building Network Services                           450.760953
# Conferencing Services                                     447.047643
# Other Activities                                          401.593005
# Fixed Line                                                376.021624
# Data Centre Facilities Management                         353.751450
# Classified Infrastructure                                 328.177442
# Storage                                                   317.129786
# Government of Canada Managed Security Service             310.943732
# Secure Remote Access                                      302.479179
# High-performance Computing                                260.660881
# Email                                                     222.807302
# Managed Secure File Transfer                              216.466111
# Directory Services                                        213.969048
# Cloud Brokering                                           206.779147
# GC WAN                                                    193.965079
# Mobile Devices                                            186.636654
# Database                                                  181.030026
# Internal Credential Management (ICM)                      179.777785
# Midrange                                                  141.473640
# Distributed Print                                         137.112983
# Mainframe                                                 119.144601
# Workplace Technology Services                             113.633950
# WTD Provisioning                                           84.590000
# Middleware                                                 59.232249
# Internet                                                   57.955714
# Facilities-as-a-service (FaaS)                              3.460000
#
#                                                BUSINESS_COMPLETION_HRS
# PARENT_SERVICE
# IT Continuity Support Service                              4219.110000
# Solutions Integration Service (SIS)                        1172.520000
# Satellite                                                   501.652927
# Bulk Print                                                  269.763333
# Firewall                                                    141.575320
# Toll-free Voice                                             136.183231
# Contact Centre                                              133.452783
# Intra-building Network Services                             129.122458
# Conferencing Services                                       126.918488
# Other Activities                                            147.080824
# Fixed Line                                                  107.172208
# Data Centre Facilities Management                           102.967497
# Classified Infrastructure                                    95.382791
# Storage                                                      90.471010
# Government of Canada Managed Security Service                92.592359
# Secure Remote Access                                         88.723682
# High-performance Computing                                   85.299092
# Email                                                        64.335737
# Managed Secure File Transfer                                 60.176806
# Directory Services                                           61.177892
# Cloud Brokering                                              61.982326
# GC WAN                                                       54.378259
# Mobile Devices                                               53.379909
# Database                                                     51.323509
# Internal Credential Management (ICM)                         52.447131
# Midrange                                                     39.615703
# Distributed Print                                            38.961303
# Mainframe                                                    33.078515
# Workplace Technology Services                                29.444811
# WTD Provisioning                                             27.363333
# Middleware                                                   15.976003
# Internet                                                     16.114286
# Facilities-as-a-service (FaaS)                                3.470000
#                                                     ACTUAL_COMPLETION_HRS  \
# service
# IT Continuity Support Service                                14735.130000
# Solutions Integration Service (SIS)                           4071.950000
# Intra-building Network Services                               2167.273525
# Satellite                                                     1750.180732
# Mainframe - zOS & zLinux                                      1683.035082
# ...                                                                   ...
# Other - Telecom & Network                                       78.888257
# Middleware                                                      59.232249
# Internet                                                        57.955714
# Service Management - Enterprise Control Center ...              30.550000
# Faciltiies-as-a-service (FaaS)                                   3.460000
#
#                                                     BUSINESS_COMPLETION_HRS
# service
# IT Continuity Support Service                                   4219.110000
# Solutions Integration Service (SIS)                             1172.520000
# Intra-building Network Services                                  620.715362
# Satellite                                                        501.652927
# Mainframe - zOS & zLinux                                         480.606475
# ...                                                                     ...
# Other - Telecom & Network                                         21.543248
# Middleware                                                        15.976003
# Internet                                                          16.114286
# Service Management - Enterprise Control Center ...                16.550000
# Faciltiies-as-a-service (FaaS)                                     3.470000
#
# [66 rows x 2 columns]
#                 ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP
# DC000157                     16104.71                  4610.70
# NW000435                     15457.16                  4431.16
# SM000541                     14735.13                  4219.11
# DC000213                     10588.50                  3034.49
# SM000575                     10558.17                  3020.00
# ...                               ...                      ...
# NW000516                          NaN                      NaN
# PM000620                          NaN                      NaN
# SM000552                          NaN                      NaN
# SM000573                          NaN                      NaN
# SM000583                          NaN                      NaN
#
# [459 rows x 2 columns]
#         ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 918.0                2984.790               843.215000
# 1237.0               2567.195               732.470000
# 948.0                1482.200               416.270000
# 1083.0               1417.575               413.983750
# 1085.0               1388.190               393.813333
# ...                       ...                      ...
# 988.0                  22.405                 5.785000
# 1732.0                 14.980                 8.200000
# 1232.0                 10.060                 0.000000
# 837.0                   0.780                 0.770000
# 1248.0                    NaN                      NaN
#
# [71 rows x 2 columns]
#         ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 918.0                2984.790               843.215000
# 1237.0               2567.195               732.470000
# 948.0                1482.200               416.270000
# 1083.0               1417.575               413.983750
# 1085.0               1388.190               393.813333
# ...                       ...                      ...
# 1732.0                 14.980                 8.200000
# 988.0                  22.405                 5.785000
# 837.0                   0.780                 0.770000
# 1232.0                 10.060                 0.000000
# 1248.0                    NaN                      NaN
#
# [71 rows x 2 columns]

# %%
"""Group by Priority"""
# Average completion time by status
avgCmplStatus = df_gb_avg(incidents, ['STATUS', 'PRIORITY'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA/Inc_avgCmplStatus_pr.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(incidents, ['PARENT_SERVICE', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA/Inc_avgCmplPS_pr.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(incidents, ['service', 'PRIORITY'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA/Inc_avgCmplServ_pr.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(incidents, ['ASSIGNED_GROUP', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA/Inc_avgCmplAG_pr.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(incidents, ['org_id', 'PRIORITY'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(incidents, ['org_id', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA/Inc_avgCmplORG_pr.csv")
avgBizORG.to_csv("./AVGDATA/Inc_avgBizORG_pr.csv")
# Out:
#                    ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS   PRIORITY
# RESOLVED Low                 2189.252234               627.426383
# INPROG   Medium              1905.213333               547.850000
#          Low                 1620.015000               448.475000
# RESOLVED Medium              1592.606757               458.791622
# CLOSED   High                 390.950069               390.950069
#          Low                  265.415804                75.782776
#          Medium               250.074190                72.515202
# SLAHOLD  Medium               145.675000                41.675000
# QUEUED   Low                   28.370000                14.370000
# AWAITVEN Medium                 8.396667                 0.000000
# QUEUED   Medium                 3.700000                 3.680000
# SLAHOLD  Low                    3.210000                 3.220000
# AWAITVEN Low                   -0.677778                 0.317778
# AWAITCHG Low                         NaN                      NaN
#          Medium                      NaN                      NaN
# AWAITCUS High                        NaN                      NaN
#          Low                         NaN                      NaN
#          Medium                      NaN                      NaN
# INPROG   High                        NaN                      NaN
# QUEUED   High                        NaN                      NaN
# SLAHOLD  High                        NaN                      NaN
#                                               ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                      PRIORITY
# IT Continuity Support Service       Medium             14735.130000
# Solutions Integration Service (SIS) Low                 4071.950000
# Other Activities                    High                2889.018672
# Satellite                           Medium              1934.070000
#                                     Low                 1674.088621
# ...                                                             ...
# Database                            High                   6.059524
# Internet                            Medium                 3.485000
# Facilities-as-a-service (FaaS)      Medium                 3.460000
# Bulk Print                          Medium                 1.395000
# Distributed Print                   High                   0.410000
#
#                                               BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                      PRIORITY
# IT Continuity Support Service       Medium                4219.110000
# Solutions Integration Service (SIS) Low                   1172.520000
# Other Activities                    High                  2889.018672
# Satellite                           Medium                 556.036667
#                                     Low                    479.149310
# ...                                                               ...
# Database                            High                     6.059524
# Internet                            Medium                   3.490000
# Facilities-as-a-service (FaaS)      Medium                   3.470000
# Bulk Print                          Medium                   1.400000
# Distributed Print                   High                     0.410000
#
# [86 rows x 2 columns]
#                                                         ACTUAL_COMPLETION_HRS  \
# service                                       PRIORITY
# IT Continuity Support Service                 Medium             14735.130000
# Other - Service Management                    High                4182.539430
# Solutions Integration Service (SIS)           Low                 4071.950000
# Mainframe - zOS & zLinux                      Medium              2985.219048
# Intra-building Network Services               Low                 2541.930014
# ...                                                                       ...
# Faciltiies-as-a-service (FaaS)                Medium                 3.460000
# Bulk Print                                    Medium                 1.395000
# Distributed Print                             High                   0.410000
# High-performance Computing                    Medium               -45.353522
# Other - Account & Service Delivery Management Medium                      NaN
#
#                                                         BUSINESS_COMPLETION_HRS
# service                                       PRIORITY
# IT Continuity Support Service                 Medium                4219.110000
# Other - Service Management                    High                  4182.539430
# Solutions Integration Service (SIS)           Low                   1172.520000
# Mainframe - zOS & zLinux                      Medium                 853.122857
# Intra-building Network Services               Low                    726.203804
# ...                                                                         ...
# Faciltiies-as-a-service (FaaS)                Medium                   3.470000
# Bulk Print                                    Medium                   1.400000
# Distributed Print                             High                     0.410000
# High-performance Computing                    Medium                  88.691748
# Other - Account & Service Delivery Management Medium                        NaN
#
# [172 rows x 2 columns]
#                          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY
# EDC00031       High                 255749.272               255749.272
# DC000157       Medium                16104.710                 4610.700
# NW000435       Low                   15457.160                 4431.160
# SM000541       Medium                14735.130                 4219.110
# NW000441       Medium                13967.890                 4019.900
# ...                                        ...                      ...
# PM000620       Low                         NaN                      NaN
# SM000500       Medium                      NaN                      NaN
# SM000552       Low                         NaN                      NaN
# SM000573       Low                         NaN                      NaN
# SM000583       Medium                      NaN                      NaN
#
# [1004 rows x 2 columns]
#                  ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY
# 918.0  Low                 5966.890000              1683.750000
# 1237.0 Low                 4763.150000              1364.160000
# 1083.0 Low                 1874.788333               545.903333
# 1085.0 Medium              1648.095000               471.575000
# 1260.0 Medium              1486.845000               423.850000
# ...                                ...                      ...
# 918.0  Medium                 2.690000                 2.680000
# 1202.0 High                   2.210000                 2.210000
# 837.0  Medium                 0.780000                 0.770000
# 988.0  Low                    0.260000                 0.250000
# 1248.0 Medium                      NaN                      NaN
#
# [182 rows x 2 columns]
#                  ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY
# 918.0  Low                 5966.890000              1683.750000
# 1032.0 High                1409.740000              1409.740000
# 1237.0 Low                 4763.150000              1364.160000
# 1342.0 High                1173.525417              1173.525417
# 1303.0 High                 615.028571               615.028571
# ...                                ...                      ...
# 1732.0 Low                   15.310000                 1.750000
# 837.0  Medium                 0.780000                 0.770000
# 988.0  Low                    0.260000                 0.250000
# 1232.0 Medium                10.060000                 0.000000
# 1248.0 Medium                      NaN                      NaN
#
# [182 rows x 2 columns]

# %%
"""Group by Priority and Status"""
# Average completion time by parent service
avgCmplPS = df_gb_avg(incidents, ['PARENT_SERVICE', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA/Inc_avgCmplPS_pr_stat.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(incidents, ['service', 'PRIORITY', 'STATUS'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA/Inc_avgCmplServ_pr_stat.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(incidents, ['ASSIGNED_GROUP', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA/Inc_avgCmplAG_pr_stat.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(incidents, ['org_id', 'PRIORITY', 'STATUS'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(incidents, ['org_id', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA/Inc_avgCmplORG_pr_stat.csv")
avgBizORG.to_csv("./AVGDATA/Inc_avgBizORG_pr_stat.csv")
# Out:
#                                                         ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                       PRIORITY STATUS
# IT Continuity Support Service        Medium   CLOSED             14735.130000
# Midrange                             Medium   RESOLVED            6480.886667
# Internal Credential Management (ICM) Medium   INPROG              5571.140000
# Solutions Integration Service (SIS)  Low      CLOSED              4071.950000
# GC WAN                               Low      RESOLVED            3144.222000
# ...                                                                       ...
# Storage                              Medium   INPROG                      NaN
#                                               QUEUED                      NaN
#                                               SLAHOLD                     NaN
# Toll-free Voice                      Medium   AWAITCUS                    NaN
#                                               QUEUED                      NaN
#
#                                                         BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                       PRIORITY STATUS
# IT Continuity Support Service        Medium   CLOSED                4219.110000
# Midrange                             Medium   RESOLVED              1860.883333
# Internal Credential Management (ICM) Medium   INPROG                1603.150000
# Solutions Integration Service (SIS)  Low      CLOSED                1172.520000
# GC WAN                               Low      RESOLVED               903.798000
# ...                                                                         ...
# Storage                              Medium   INPROG                        NaN
#                                               QUEUED                        NaN
#                                               SLAHOLD                       NaN
# Toll-free Voice                      Medium   AWAITCUS                      NaN
#                                               QUEUED                        NaN
#
# [268 rows x 2 columns]
#                                                         ACTUAL_COMPLETION_HRS  \
# service                              PRIORITY STATUS
# IT Continuity Support Service        Medium   CLOSED             14735.130000
# Midrange - Windows -X86              Medium   RESOLVED            6480.886667
# Data Centre Facilities Management    Medium   RESOLVED            6382.660000
# Internal Credential Management (ICM) Medium   INPROG              5571.140000
# Other - Internal Services & Strategy Low      RESOLVED            4613.043333
# ...                                                                       ...
# Storage - File                       Low      INPROG                      NaN
#                                      Medium   AWAITCUS                    NaN
#                                               INPROG                      NaN
# Toll-free Voice                      Medium   AWAITCUS                    NaN
#                                               QUEUED                      NaN
#
#                                                         BUSINESS_COMPLETION_HRS
# service                              PRIORITY STATUS
# IT Continuity Support Service        Medium   CLOSED                4219.110000
# Midrange - Windows -X86              Medium   RESOLVED              1860.883333
# Data Centre Facilities Management    Medium   RESOLVED              1818.670000
# Internal Credential Management (ICM) Medium   INPROG                1603.150000
# Other - Internal Services & Strategy Low      RESOLVED              1321.710000
# ...                                                                         ...
# Storage - File                       Low      INPROG                        NaN
#                                      Medium   AWAITCUS                      NaN
#                                               INPROG                        NaN
# Toll-free Voice                      Medium   AWAITCUS                      NaN
#                                               QUEUED                        NaN
#
# [444 rows x 2 columns]
#                                   ACTUAL_COMPLETION_HRS  \
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED               255749.272
# DC000157       Medium   RESOLVED              16104.710
# NW000435       Low      CLOSED                15457.160
# SM000541       Medium   CLOSED                14735.130
# NW000441       Medium   CLOSED                13967.890
# ...                                                 ...
# SM000585       Medium   INPROG                      NaN
# SM000586       Low      AWAITCUS                    NaN
#                         SLAHOLD                     NaN
#                Medium   AWAITCUS                    NaN
#                         SLAHOLD                     NaN
#
#                                   BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED                 255749.272
# DC000157       Medium   RESOLVED                 4610.700
# NW000435       Low      CLOSED                   4431.160
# SM000541       Medium   CLOSED                   4219.110
# NW000441       Medium   CLOSED                   4019.900
# ...                                                   ...
# SM000585       Medium   INPROG                        NaN
# SM000586       Low      AWAITCUS                      NaN
#                         SLAHOLD                       NaN
#                Medium   AWAITCUS                      NaN
#                         SLAHOLD                       NaN
#
# [1474 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            6437.906667              1847.866667
# 1273.0 Medium   RESOLVED            6382.660000              1818.670000
# 918.0  Low      CLOSED              5966.890000              1683.750000
# 1045.0 Medium   RESOLVED            5835.846667              1674.343333
# 1047.0 Low      RESOLVED            5672.427500              1623.267500
# ...                                         ...                      ...
# 1355.0 Medium   AWAITCUS                    NaN                      NaN
# 1377.0 High     QUEUED                      NaN                      NaN
#        Low      INPROG                      NaN                      NaN
#        Medium   QUEUED                      NaN                      NaN
# 1753.0 Medium   QUEUED                      NaN                      NaN
#
# [473 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            6437.906667              1847.866667
# 1273.0 Medium   RESOLVED            6382.660000              1818.670000
# 918.0  Low      CLOSED              5966.890000              1683.750000
# 1045.0 Medium   RESOLVED            5835.846667              1674.343333
# 1047.0 Low      RESOLVED            5672.427500              1623.267500
# ...                                         ...                      ...
# 1355.0 Medium   AWAITCUS                    NaN                      NaN
# 1377.0 High     QUEUED                      NaN                      NaN
#        Low      INPROG                      NaN                      NaN
#        Medium   QUEUED                      NaN                      NaN
# 1753.0 Medium   QUEUED                      NaN                      NaN
#
# [473 rows x 2 columns]

# %% [markdown]
# # Event Management

# %%
"""Just Event Management"""
# Filter for event management tickets
jemInc = incidents[incidents["EXTERNAL_SYSTEM"] == "EVENTMANAGEMENT"]

# Reset index
jemInc = jemInc.reset_index(drop=True)

# Filter Incident owner history for event management tickets
jemIOH = incOwnHist[incOwnHist["ticket_nmbr"].isin(jemInc["TICKET_NMBR"])]

# Reset index
jemIOH = jemIOH.reset_index(drop=True)

# Display
display(jemInc)
display(jemIOH)
# Out:
#       TICKET_NMBR                   PARENT_SERVICE  \
# 0      IN10028612                       Middleware
# 1      IN10028613                         Midrange
# 2      IN10028615       High-performance Computing
# 3      IN10028617                         Midrange
# 4      IN10028618                 Other Activities
# ...           ...                              ...
# 96960  IN10293537  Intra-building Network Services
# 96961  IN10293538                       Middleware
# 96962  IN10293540       High-performance Computing
# 96963  IN10293541                         Midrange
# 96964  IN10293552                        Mainframe
#
#                           service  org_id ASSIGNED_GROUP           OPEN_DATE  \
# 0                      Middleware  1342.0       DC000152  01APR2016:00:01:16
# 1         Midrange - Windows -X86  1342.0       NDS00032  01APR2016:00:35:21
# 2      High-performance Computing  1342.0       DC000133  01APR2016:02:57:00
# 3         Midrange - Windows -X86  1342.0       DC000115  01APR2016:06:21:10
# 4      Other - Service Management  1342.0       ESI00011  01APR2016:06:30:34
# ...                           ...     ...            ...                 ...
# 96960                IBN - GC LAN  1047.0       NW000405  30NOV2021:20:54:25
# 96961                  Middleware  1047.0       DC000152  30NOV2021:21:21:23
# 96962  High-performance Computing  1062.0       DC000132  30NOV2021:21:42:14
# 96963                    Midrange  1342.0       DC000209  30NOV2021:21:44:01
# 96964                   Mainframe  1047.0       DC000155  30NOV2021:23:38:56
#
#                CLOSE_DATE PRIORITY    STATUS  ACTUAL_COMPLETION_HRS  \
# 0      01APR2016:08:26:30      Low    CLOSED                   8.42
# 1      11APR2016:11:06:12      Low    CLOSED                 250.51
# 2      01APR2016:07:42:08      Low    CLOSED                   4.75
# 3      18APR2016:13:09:13   Medium    CLOSED                 414.80
# 4      17APR2016:19:40:25   Medium    CLOSED                 397.16
# ...                   ...      ...       ...                    ...
# 96960  10DEC2021:08:38:54   Medium  RESOLVED                 227.74
# 96961  03DEC2021:06:42:48      Low    CLOSED                  57.36
# 96962                 NaN      Low  AWAITVEN                    NaN
# 96963  01DEC2021:08:37:06      Low    CLOSED                  10.88
# 96964  01DEC2021:03:10:13   Medium    CLOSED                   3.52
#
#        BUSINESS_COMPLETION_HRS      AGING CLASS_STRUCTURE_ID  \
# 0                         1.43        NaN               2101
# 1                        64.10        NaN                 21
# 2                         0.70        NaN               3102
# 3                       116.15        NaN               2101
# 4                       110.00        NaN               2102
# ...                        ...        ...                ...
# 96960                    71.63        NaN               2103
# 96961                    20.00        NaN               2102
# 96962                      NaN  19.658366               2102
# 96963                     1.62        NaN                 21
# 96964                     0.00        NaN               8004
#
#                      class_structure CLASSIFICATION_ID    classification  \
# 0                IT Issue \ Hardware              2101    Hardware Issue
# 1                           IT Issue                21          IT Issue
# 2      IT Request \ Software Request              3102  Software Request
# 3                IT Issue \ Hardware              2101    Hardware Issue
# 4                IT Issue \ Software              2102    Software Issue
# ...                              ...               ...               ...
# 96960            IT Issue \ Networks              2103    Networks Issue
# 96961            IT Issue \ Software              2102    Software Issue
# 96962            IT Issue \ Software              2102    Software Issue
# 96963                       IT Issue                21          IT Issue
# 96964         IT Issue \ Application              2107       Application
#
#        EXTERNAL_SYSTEM  GLOBAL_TICKET_ID CLOSURE_CODE  LAST_MODIFIED_DATE
# 0      EVENTMANAGEMENT               NaN          OTH  12APR2016:05:30:11
# 1      EVENTMANAGEMENT               NaN          CIS  22APR2016:05:30:33
# 2      EVENTMANAGEMENT               NaN          OSD  12APR2016:05:30:10
# 3      EVENTMANAGEMENT               NaN          BSR  29APR2016:05:30:36
# 4      EVENTMANAGEMENT               NaN          INF  28APR2016:05:30:07
# ...                ...               ...          ...                 ...
# 96960  EVENTMANAGEMENT               NaN         RWOI  10DEC2021:08:38:54
# 96961  EVENTMANAGEMENT               NaN           RP  14DEC2021:05:30:16
# 96962  EVENTMANAGEMENT               NaN           RP  30NOV2021:21:51:26
# 96963  EVENTMANAGEMENT               NaN           RP  12DEC2021:05:30:09
# 96964  EVENTMANAGEMENT               NaN           RP  11DEC2021:05:30:26
#
# [96965 rows x 20 columns]
#        ticket_nmbr    STATUS assigned_group    PARENT_SERVICE  \
# 0       IN10028612    QUEUED       DC000152        Middleware
# 1       IN10028612  RESOLVED       DC000152        Middleware
# 2       IN10028612    CLOSED       DC000152        Middleware
# 3       IN10028613    QUEUED       NDS00032          Midrange
# 4       IN10028613  RESOLVED       NDS00032          Midrange
# ...            ...       ...            ...               ...
# 420311  IN10293541       NEW            NaN               NaN
# 420312  IN10293552    INPROG       SM000562  Other Activities
# 420313  IN10293552    QUEUED       SM000562  Other Activities
# 420314  IN10293552    INPROG       DC000155         Mainframe
# 420315  IN10293552  RESOLVED       DC000155         Mainframe
#
#                            service         CHANGE_DATE  \
# 0                       Middleware  01APR2016:00:03:12
# 1                       Middleware  01APR2016:08:26:30
# 2                       Middleware  12APR2016:05:30:11
# 3          Midrange - Windows -X86  01APR2016:01:04:45
# 4          Midrange - Windows -X86  11APR2016:11:06:12
# ...                            ...                 ...
# 420311                         NaN                 NaN
# 420312  Other - Service Management                 NaN
# 420313  Other - Service Management                 NaN
# 420314                   Mainframe                 NaN
# 420315                   Mainframe                 NaN
#
#         TIME_IN_STATUS_BY_OWNER_HRS
# 0                          8.383333
# 1                          0.000000
# 2                               NaN
# 3                         64.100000
# 4                          0.000000
# ...                             ...
# 420311                          NaN
# 420312                     0.000000
# 420313                          NaN
# 420314                          NaN
# 420315                     0.000000
#
# [420316 rows x 7 columns]

# %%
# Average time incidents spend in particular status
avgTimeStatus = df_gb_avg(jemIOH, ['STATUS'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeStatus.to_csv("./AVGDATA_JEM/jemIOH_avgTimeStatus.csv")

# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(jemIOH, ['assigned_group'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_JEM/jemIOH_avgTimeAG.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(jemIOH, ['PARENT_SERVICE'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA_JEM/jemIOH_avgTimePS.csv")

# Average time incidents spend by service
avgTimeAG = df_gb_avg(jemIOH, ['service'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_JEM/jemIOH_avgTimeServ.csv")
# Out:
#             TIME_IN_STATUS_BY_OWNER_HRS
# STATUS
# AWAITVEN                     167.117355
# PENDINGVEN                    88.863389
# SLAHOLD                       73.841899
# AWAITCHG                      66.540715
# AWAITCUS                      58.563833
# PENDINGREV                    48.973810
# PENDINGCHG                    40.213333
# PENDING                       32.912584
# PENDINGCUS                    23.423246
# INPROG                        19.373189
# QUEUED                        14.187864
# HISTEDIT                       2.377778
# RESOLVED                       0.086900
# NEW                            0.000000
# CLOSED                              NaN
#                 TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group
# ESI00052                        2772.372917
# ITS00352                        2502.758333
# DC000145                        1724.883333
# NW000469                        1639.416667
# ITS00329                        1422.923016
# ...                                     ...
# EDC00041                           0.000000
# NW000467                           0.000000
# DC000226                                NaN
# ITS00373                                NaN
# ITS00400                                NaN
#
# [322 rows x 1 columns]
#                                                TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE
# Bulk Print                                                     1724.883333
# Distributed Print                                               319.450000
# Classified Infrastructure                                       290.000000
# Firewall                                                         44.564273
# Managed Secure File Transfer                                     26.101613
# High-performance Computing                                       25.617979
# Email                                                            24.196342
# Database                                                         21.292119
# Internal Credential Management (ICM)                             18.915646
# Data Centre Facilities Management                                17.377486
# Intra-building Network Services                                  17.048038
# Other Activities                                                 16.137184
# Toll-free Voice                                                  15.808333
# Directory Services                                               13.674057
# Mainframe                                                        13.657765
# Storage                                                          12.792047
# Conferencing Services                                            10.826754
# Secure Remote Access                                             10.386211
# Midrange                                                          9.648952
# Workplace Technology Services                                     8.953232
# Fixed Line                                                        8.442157
# Mobile Devices                                                    8.393838
# GC WAN                                                            7.766380
# Contact Centre                                                    6.612602
# Government of Canada Managed Security Service                     5.700000
# Cloud Brokering                                                   5.403983
# Middleware                                                        4.175667
#                                                     TIME_IN_STATUS_BY_OWNER_HRS
# service
# Bulk Print                                                          1724.883333
# Mobile Devices                                                       638.362500
# Distributed Print                                                    319.450000
# Classified Infrastructure - GCSI - Hosting Envi...                   290.000000
# Mainframe - zOS & zLinux                                             251.863226
# Intra-building Network Services                                      122.159201
# Other - Security                                                      93.827952
# Firewall                                                              44.564273
# Other - Internal Services & Strategy                                  42.347312
# High-performance Computing                                            33.040201
# Midrange - Storage and Virtualization                                 27.085609
# Facilities - Data Centre Facilities Racking & S...                    26.369173
# Managed Secure File Transfer                                          26.101613
# GC WAN National                                                       25.908069
# IBN - Data Centre Network                                             25.182632
# Email                                                                 24.196342
# Mobile - Mobile Device - Government Cellular Se...                    21.650000
# Mobile - Voice & Data                                                 21.483333
# Database                                                              21.292119
# Other - Project Management & Delivery                                 19.691667
# Internal Credential Management (ICM)                                  18.915646
# Other - Data Centre                                                   18.649236
# Facilities - Data Centre Facilities Power & Space                     18.437624
# Data Centre Facilities Management                                     16.244011
# Toll-free Voice                                                       15.808333
# Midrange                                                              15.197849
# Other - Service Management                                            14.202895
# Directory Services                                                    13.674057
# Storage                                                               13.001626
# IBN - GC LAN                                                          12.861148
# Conferencing - Videoconferencing                                      10.826754
# IBN - GC Wi-Fi                                                        10.715846
# Secure Remote Access                                                  10.386211
# Fixed Line                                                            10.101282
# Workplace Technology Services                                          8.953232
# IBN - Cabling - Install and Material                                   8.389962
# Midrange - Windows -X86                                                7.568455
# Mainframe                                                              7.567126
# GC WAN                                                                 7.525620
# Contact Centre                                                         6.612602
# Mobile - Enterprise Mobile Device Management (E...                     6.592775
# HPC -Big Data Exchange                                                 6.222748
# Government of Canada Managed Security Service                          5.700000
# Cloud Brokering                                                        5.403983
# Other - Telecom & Network                                              5.368789
# Storage - File                                                         4.843750
# Middleware                                                             4.175667
# Fixed - VoIP                                                           3.050000
# HPC - Interaction & Visualization                                      2.996704

# %%
"""Group By Status"""
# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(jemIOH, ['assigned_group', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_JEM/jemIOH_avgTimeAGStatus.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(jemIOH, ['PARENT_SERVICE', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA_JEM/jemIOH_avgTimePSStatus.csv")

# Average time incidents spend by service
avgTimeAG = df_gb_avg(jemIOH, ['service', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_JEM/jemIOH_avgTimeServStatus.csv")
# Out:
#                          TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group STATUS
# DC000118       QUEUED                    5559.466667
# ITS00340       AWAITCUS                  5552.816667
# ESI00052       AWAITCUS                  5550.833333
# ITS00329       AWAITCUS                  5446.583333
#                QUEUED                    3490.685714
# ...                                              ...
# SM000562       CLOSED                            NaN
# SM000585       AWAITCUS                          NaN
#                CLOSED                            NaN
# SM000586       CLOSED                            NaN
# TIVMON         CLOSED                            NaN
#
# [1480 rows x 1 columns]
#                                               TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE                    STATUS
# Bulk Print                        QUEUED                      2111.008333
#                                   INPROG                       952.633333
# Secure Remote Access              AWAITCUS                     727.808333
# Data Centre Facilities Management PENDINGVEN                   584.444444
# Email                             AWAITCUS                     570.076667
# ...                                                                   ...
# Other Activities                  CLOSED                              NaN
# Secure Remote Access              AWAITCHG                            NaN
#                                   CLOSED                              NaN
# Storage                           CLOSED                              NaN
# Workplace Technology Services     CLOSED                              NaN
#
# [221 rows x 1 columns]
#                                         TIME_IN_STATUS_BY_OWNER_HRS
# service                       STATUS
# Bulk Print                    QUEUED                    2111.008333
# Other - Security              AWAITCUS                  1468.991667
# Mobile Devices                INPROG                    1321.333333
#                               QUEUED                    1010.000000
# Bulk Print                    INPROG                     952.633333
# ...                                                             ...
# Secure Remote Access          AWAITCHG                          NaN
#                               CLOSED                            NaN
# Storage                       CLOSED                            NaN
# Storage - File                CLOSED                            NaN
# Workplace Technology Services CLOSED                            NaN
#
# [365 rows x 1 columns]

# %%
# Average completion time by status
avgCmplStatus = df_gb_avg(jemInc, ['STATUS'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA_JEM/jemInc_avgCmplStatus.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(jemInc, ['PARENT_SERVICE'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_JEM/jemInc_avgCmplPS.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(jemInc, ['service'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_JEM/jemInc_avgCmplServ.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(jemInc, ['ASSIGNED_GROUP'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_JEM/jemInc_avgCmplAG.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(jemInc, ['org_id'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(jemInc, ['org_id'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_JEM/jemInc_avgCmplORG.csv")
avgBizORG.to_csv("./AVGDATA_JEM/jemInc_avgBizORG.csv")
# Out:
#           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS
# RESOLVED            2568.350213               737.081915
# INPROG               955.990000               264.800000
# CLOSED               122.551871                43.918936
# QUEUED                28.370000                14.370000
# AWAITVEN               4.216667                 0.292222
# AWAITCUS                    NaN                      NaN
# SLAHOLD                     NaN                      NaN
#                                                ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE
# Firewall                                                  334.168306
# Other Activities                                          311.433446
# High-performance Computing                                228.265096
# Email                                                     197.513241
# Internal Credential Management (ICM)                      173.175082
# Intra-building Network Services                           134.191680
# Database                                                  113.763271
# Workplace Technology Services                             108.331128
# Mainframe                                                 101.080406
# Data Centre Facilities Management                          91.339244
# Directory Services                                         90.410906
# Secure Remote Access                                       86.932541
# Midrange                                                   81.611362
# Cloud Brokering                                            79.867973
# Storage                                                    68.340549
# GC WAN                                                     67.074588
# Conferencing Services                                      63.394615
# Mobile Devices                                             61.308249
# Fixed Line                                                 54.435000
# Government of Canada Managed Security Service              39.071250
# Contact Centre                                             34.406223
# Managed Secure File Transfer                               28.863333
# Middleware                                                 24.697767
#
#                                                BUSINESS_COMPLETION_HRS
# PARENT_SERVICE
# Firewall                                                     94.297132
# Other Activities                                            187.417807
# High-performance Computing                                   66.235825
# Email                                                        55.943657
# Internal Credential Management (ICM)                         46.918033
# Intra-building Network Services                              36.432287
# Database                                                     32.698271
# Workplace Technology Services                                27.255668
# Mainframe                                                    27.666743
# Data Centre Facilities Management                            29.602430
# Directory Services                                           25.349151
# Secure Remote Access                                         25.147727
# Midrange                                                     21.926172
# Cloud Brokering                                              21.341081
# Storage                                                      18.728566
# GC WAN                                                       17.713403
# Conferencing Services                                         8.395385
# Mobile Devices                                               16.546647
# Fixed Line                                                   15.062500
# Government of Canada Managed Security Service                10.373750
# Contact Centre                                               14.412410
# Managed Secure File Transfer                                  2.188333
# Middleware                                                    5.743201
#                                                     ACTUAL_COMPLETION_HRS  \
# service
# Mainframe - zOS & zLinux                                      1969.112875
# Intra-building Network Services                               1303.024045
# Other - Security                                               494.226139
# Firewall                                                       334.168306
# Other - Service Management                                     320.901298
# High-performance Computing                                     314.712877
# Email                                                          197.513241
# Internal Credential Management (ICM)                           173.175082
# Other - Project Management & Delivery                          153.010000
# Other - Data Centre                                            150.314180
# Facilities - Data Centre Facilities Power & Space              149.952121
# -1                                                             136.348122
# Midrange - Storage and Virtualization                          134.839195
# Midrange                                                       131.429144
# Facilities - Data Centre Facilities Racking & S...             127.141373
# GC WAN National                                                119.599055
# Database                                                       113.763271
# IBN - GC LAN                                                   112.248359
# Workplace Technology Services                                  108.331128
# IBN - Data Centre Network                                      107.781324
# IBN - GC Wi-Fi                                                  96.388517
# Directory Services                                              90.410906
# Secure Remote Access                                            86.932541
# Other - Internal Services & Strategy                            85.344000
# Data Centre Facilities Management                               81.134301
# Cloud Brokering                                                 79.867973
# Storage - File                                                  72.604000
# Storage                                                         68.263730
# IBN - Cabling - Install and Material                            67.328571
# GC WAN                                                          66.462381
# Mainframe                                                       63.607337
# Conferencing - Videoconferencing                                63.394615
# Mobile - Enterprise Mobile Device Management (E...              61.308249
# Midrange - Windows -X86                                         60.197846
# Fixed Line                                                      54.435000
# Other - Telecom & Network                                       39.331509
# Government of Canada Managed Security Service                   39.071250
# Contact Centre                                                  34.406223
# Managed Secure File Transfer                                    28.863333
# HPC - Interaction & Visualization                               26.981813
# Middleware                                                      24.697767
# HPC -Big Data Exchange                                          22.190731
#
#                                                     BUSINESS_COMPLETION_HRS
# service
# Mainframe - zOS & zLinux                                         561.594500
# Intra-building Network Services                                  372.335909
# Other - Security                                                 140.868399
# Firewall                                                          94.297132
# Other - Service Management                                       206.286496
# High-performance Computing                                        90.003782
# Email                                                             55.943657
# Internal Credential Management (ICM)                              46.918033
# Other - Project Management & Delivery                             41.130000
# Other - Data Centre                                               43.555434
# Facilities - Data Centre Facilities Power & Space                 43.036970
# -1                                                                39.477918
# Midrange - Storage and Virtualization                             38.597241
# Midrange                                                          36.674984
# Facilities - Data Centre Facilities Racking & S...                37.932941
# GC WAN National                                                   34.144488
# Database                                                          32.698271
# IBN - GC LAN                                                      30.192191
# Workplace Technology Services                                     27.255668
# IBN - Data Centre Network                                         28.464136
# IBN - GC Wi-Fi                                                    25.317376
# Directory Services                                                25.349151
# Secure Remote Access                                              25.147727
# Other - Internal Services & Strategy                              26.532000
# Data Centre Facilities Management                                 27.252007
# Cloud Brokering                                                   21.341081
# Storage - File                                                    25.115000
# Storage                                                           18.613495
# IBN - Cabling - Install and Material                              21.670936
# GC WAN                                                            17.521888
# Mainframe                                                         16.956056
# Conferencing - Videoconferencing                                   8.395385
# Mobile - Enterprise Mobile Device Management (E...                16.546647
# Midrange - Windows -X86                                           15.583220
# Fixed Line                                                        15.062500
# Other - Telecom & Network                                         10.243501
# Government of Canada Managed Security Service                     10.373750
# Contact Centre                                                    14.412410
# Managed Secure File Transfer                                       2.188333
# HPC - Interaction & Visualization                                  7.636133
# Middleware                                                         5.743201
# HPC -Big Data Exchange                                             9.913141
#                 ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP
# ITS00329                   8234.61000              2360.126923
# DC000168                   6053.32000              1733.680000
# ITS00353                   5674.99375              1622.812500
# EDC00065                   4159.62000              1206.150000
# NW000490                   3564.91000              1025.910000
# ...                               ...                      ...
# EU000203                      0.42000                 0.420000
# NDS00039                      0.36000                 0.370000
# NW000457                      0.31000                 0.300000
# DC000166                      0.15000                 0.150000
# DC000226                          NaN                      NaN
#
# [231 rows x 2 columns]
#          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 1083.0             4922.660000              1427.775000
# 1213.0              794.244130               222.682174
# 1067.0              757.639091               206.811818
# 1017.0              672.730000               190.740000
# 877.0               406.147857               115.354643
# 1040.0              330.750000                94.657059
# 992.0               308.160000                86.514706
# 1123.0              265.573393                73.196786
# 15833.0             251.928750                67.688125
# 1068.0              229.989375                64.426875
# 1062.0              215.685952                62.591154
# 1205.0              200.220000                53.566000
# 1165.0              186.020345                49.902759
# 1055.0              153.855388                41.691240
# 1053.0              137.537000                34.014000
# 1342.0              134.775859                59.188507
# 1087.0              127.173333                36.495000
# 1028.0              121.623247                33.264143
# 1355.0              108.402078                29.181499
# 1037.0              103.555152                25.743485
# 1228.0              101.441667                20.924167
# 1058.0               98.275870                30.875217
# 910.0                96.018240                25.731360
# 835.0                92.680958                25.053533
# 1045.0               91.840132                23.270658
# 1272.0               85.365841                22.845619
# 942.0                83.517379                22.854075
# 1060.0               81.638333                24.283333
# 912.0                68.585000                13.726000
# 1050.0               60.090658                15.709671
# 1047.0               53.467610                14.938453
# 1063.0               53.436202                12.512019
# 1065.0               51.111062                14.032174
# 1042.0               50.962222                11.201667
# 1303.0               48.663571                14.432857
# 853.0                37.954000                 9.877455
# 1057.0               32.002200                 7.044200
# 1048.0               31.248333                 2.975000
# 1038.0               26.908889                 5.973333
# 1297.0               16.400000                 2.410000
# 17498.0              14.060000                 3.520000
#          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 1083.0             4922.660000              1427.775000
# 1213.0              794.244130               222.682174
# 1067.0              757.639091               206.811818
# 1017.0              672.730000               190.740000
# 877.0               406.147857               115.354643
# 1040.0              330.750000                94.657059
# 992.0               308.160000                86.514706
# 1123.0              265.573393                73.196786
# 15833.0             251.928750                67.688125
# 1068.0              229.989375                64.426875
# 1062.0              215.685952                62.591154
# 1342.0              134.775859                59.188507
# 1205.0              200.220000                53.566000
# 1165.0              186.020345                49.902759
# 1055.0              153.855388                41.691240
# 1087.0              127.173333                36.495000
# 1053.0              137.537000                34.014000
# 1028.0              121.623247                33.264143
# 1058.0               98.275870                30.875217
# 1355.0              108.402078                29.181499
# 1037.0              103.555152                25.743485
# 910.0                96.018240                25.731360
# 835.0                92.680958                25.053533
# 1060.0               81.638333                24.283333
# 1045.0               91.840132                23.270658
# 942.0                83.517379                22.854075
# 1272.0               85.365841                22.845619
# 1228.0              101.441667                20.924167
# 1050.0               60.090658                15.709671
# 1047.0               53.467610                14.938453
# 1303.0               48.663571                14.432857
# 1065.0               51.111062                14.032174
# 912.0                68.585000                13.726000
# 1063.0               53.436202                12.512019
# 1042.0               50.962222                11.201667
# 853.0                37.954000                 9.877455
# 1057.0               32.002200                 7.044200
# 1038.0               26.908889                 5.973333
# 17498.0              14.060000                 3.520000
# 1048.0               31.248333                 2.975000
# 1297.0               16.400000                 2.410000

# %%
"""Group by Priority"""
# Average completion time by status
avgCmplStatus = df_gb_avg(jemInc, ['STATUS', 'PRIORITY'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA_JEM/jemInc_avgCmplStatus_pr.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(jemInc, ['PARENT_SERVICE', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_JEM/jemInc_avgCmplPS_pr.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(jemInc, ['service', 'PRIORITY'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_JEM/jemInc_avgCmplServ_pr.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(jemInc, ['ASSIGNED_GROUP', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_JEM/jemInc_avgCmplAG_pr.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(jemInc, ['org_id', 'PRIORITY'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(jemInc, ['org_id', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_JEM/jemInc_avgCmplORG_pr.csv")
avgBizORG.to_csv("./AVGDATA_JEM/jemInc_avgBizORG_pr.csv")
# Out:
#                    ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS   PRIORITY
# RESOLVED Low                 3163.196333               905.492667
# INPROG   Low                 1911.870000               529.600000
# RESOLVED Medium              1518.621765               439.886471
# CLOSED   High                 837.543947               837.543947
#          Low                  122.606400                34.244421
#          Medium                64.994634                17.593648
# QUEUED   Low                   28.370000                14.370000
# AWAITVEN Medium                 8.396667                 0.000000
#          Low                    2.126667                 0.438333
# INPROG   Medium                 0.110000                 0.000000
# AWAITCUS Low                         NaN                      NaN
# QUEUED   Medium                      NaN                      NaN
# SLAHOLD  Low                         NaN                      NaN
#          Medium                      NaN                      NaN
#                                                         ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                                PRIORITY
# Other Activities                              High               10687.821000
# Firewall                                      Low                  369.845076
# Email                                         Low                  289.634545
# Other Activities                              Low                  250.155151
# High-performance Computing                    Low                  238.201001
# Mainframe                                     Low                  201.895585
# Internal Credential Management (ICM)          Low                  175.780169
# High-performance Computing                    High                 147.878621
# Data Centre Facilities Management             Low                  139.458621
# Intra-building Network Services               Low                  135.294067
#                                               Medium               133.753041
# Secure Remote Access                          Low                  125.884364
# High-performance Computing                    Medium               118.146835
# Database                                      Low                  114.982749
# Workplace Technology Services                 Low                  110.864448
# Midrange                                      Medium               106.629494
# Directory Services                            Low                   97.451126
# Firewall                                      Medium                96.692697
# Internal Credential Management (ICM)          Medium                96.325000
# Fixed Line                                    Low                   93.760000
# Secure Remote Access                          Medium                84.264608
# Data Centre Facilities Management             Medium                80.951856
# Cloud Brokering                               Low                   79.867973
# Midrange                                      Low                   79.711229
# Conferencing Services                         Medium                75.385000
# Storage                                       Low                   72.878330
# GC WAN                                        Low                   71.488268
# Storage                                       High                  68.556667
# Mainframe                                     Medium                62.013086
# Mobile Devices                                Low                   61.364405
# Conferencing Services                         Low                   61.214545
# Directory Services                            Medium                56.150606
# GC WAN                                        Medium                54.456997
#                                               High                  52.628687
# Other Activities                              Medium                49.240088
# Midrange                                      High                  45.621257
# Mobile Devices                                Medium                42.440000
# Intra-building Network Services               High                  41.252530
# Database                                      Medium                40.040000
# Government of Canada Managed Security Service Low                   39.071250
# Contact Centre                                High                  37.832407
#                                               Medium                36.542927
# Storage                                       Medium                35.556029
# Workplace Technology Services                 Medium                33.252727
# Contact Centre                                Low                   31.869437
# Middleware                                    Medium                29.132321
# Managed Secure File Transfer                  Low                   28.863333
# Data Centre Facilities Management             High                  25.893333
# Middleware                                    Low                   24.225310
# Email                                         High                  20.793333
# Fixed Line                                    High                  17.500000
# Directory Services                            High                  17.031000
# Email                                         Medium                17.017647
# Fixed Line                                    Medium                12.720000
# Firewall                                      High                  10.501364
# Middleware                                    High                   6.971326
# Database                                      High                   3.900000
# Mainframe                                     High                   1.740000
#
#                                                         BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                                PRIORITY
# Other Activities                              High                 10687.821000
# Firewall                                      Low                    104.116250
# Email                                         Low                     81.879860
# Other Activities                              Low                     77.155713
# High-performance Computing                    Low                     68.884260
# Mainframe                                     Low                     55.723755
# Internal Credential Management (ICM)          Low                     47.650000
# High-performance Computing                    High                   147.878621
# Data Centre Facilities Management             Low                     38.980805
# Intra-building Network Services               Low                     36.237798
#                                               Medium                  37.205445
# Secure Remote Access                          Low                     36.274909
# High-performance Computing                    Medium                  33.802113
# Database                                      Low                     33.094313
# Workplace Technology Services                 Low                     27.875951
# Midrange                                      Medium                  29.129305
# Directory Services                            Low                     27.324642
# Firewall                                      Medium                  27.631573
# Internal Credential Management (ICM)          Medium                  25.325000
# Fixed Line                                    Low                     20.465000
# Secure Remote Access                          Medium                  24.385592
# Data Centre Facilities Management             Medium                  22.438068
# Cloud Brokering                               Low                     21.341081
# Midrange                                      Low                     21.195178
# Conferencing Services                         Medium                   8.655000
# Storage                                       Low                     19.816965
# GC WAN                                        Low                     18.368521
# Storage                                       High                    68.556667
# Mainframe                                     Medium                  16.793076
# Mobile Devices                                Low                     16.595893
# Conferencing Services                         Low                      8.348182
# Directory Services                            Medium                  14.496061
# GC WAN                                        Medium                  14.504987
#                                               High                    52.628687
# Other Activities                              Medium                  13.377255
# Midrange                                      High                    45.621257
# Mobile Devices                                Medium                   0.000000
# Intra-building Network Services               High                    41.252530
# Database                                      Medium                   5.315000
# Government of Canada Managed Security Service Low                     10.373750
# Contact Centre                                High                    37.832407
#                                               Medium                   9.453171
# Storage                                       Medium                   6.473088
# Workplace Technology Services                 Medium                   8.872727
# Contact Centre                                Low                      8.370000
# Middleware                                    Medium                   6.842109
# Managed Secure File Transfer                  Low                      2.188333
# Data Centre Facilities Management             High                    25.893333
# Middleware                                    Low                      4.909792
# Email                                         High                    20.793333
# Fixed Line                                    High                    17.500000
# Directory Services                            High                    17.031000
# Email                                         Medium                   4.974602
# Fixed Line                                    Medium                   1.820000
# Firewall                                      High                    10.501364
# Middleware                                    High                     6.971326
# Database                                      High                     3.900000
# Mainframe                                     High                     1.740000
#                                             ACTUAL_COMPLETION_HRS  \
# service                           PRIORITY
# Other - Service Management        High               11245.040965
# Mainframe - zOS & zLinux          Medium              3347.024615
#                                   Low                 1701.756866
# Intra-building Network Services   Low                 1694.976369
# GC WAN National                   Medium              1394.360000
# ...                                                           ...
# HPC - Interaction & Visualization Medium                 3.627843
# Intra-building Network Services   High                   3.574118
# Mainframe                         High                   1.740000
# -1                                Medium                 1.185385
# Storage - File                    High                   0.420000
#
#                                             BUSINESS_COMPLETION_HRS
# service                           PRIORITY
# Other - Service Management        High                 11245.040965
# Mainframe - zOS & zLinux          Medium                 956.189231
#                                   Low                    485.031343
# Intra-building Network Services   Low                    483.808393
# GC WAN National                   Medium                 403.145000
# ...                                                             ...
# HPC - Interaction & Visualization Medium                   0.820196
# Intra-building Network Services   High                     3.574118
# Mainframe                         High                     1.740000
# -1                                Medium                   0.199231
# Storage - File                    High                     0.420000
#
# [103 rows x 2 columns]
#                          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY
# EDC00031       High               255749.27200            255749.272000
# ITS00329       Low                  8234.61000              2360.126923
# DC000168       Low                  6053.32000              1733.680000
# ITS00353       Low                  5674.99375              1622.812500
# NW000490       Low                  5567.63000              1589.630000
# ...                                        ...                      ...
# EU000203       High                    0.42000                 0.420000
# NDS00039       Low                     0.36000                 0.370000
# NW000457       Low                     0.31000                 0.300000
# DC000166       Low                     0.15000                 0.150000
# DC000226       Low                         NaN                      NaN
#
# [399 rows x 2 columns]
#                  ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY
# 1083.0 Low                 4922.660000              1427.775000
# 1342.0 High                1878.969913              1878.969913
# 1123.0 Medium              1489.995000               427.850000
# 1067.0 Low                  828.685000               226.576000
# 1213.0 Low                  794.244130               222.682174
# ...                                ...                      ...
# 1047.0 High                  10.732409                10.732409
# 835.0  High                   8.170000                 8.170000
# 1057.0 Medium                 4.780000                 4.770000
# 1065.0 High                   4.593548                 4.593548
# 1037.0 High                   1.442500                 1.442500
#
# [82 rows x 2 columns]
#                   ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id  PRIORITY
# 1342.0  High                1878.969913              1878.969913
# 1083.0  Low                 4922.660000              1427.775000
# 1123.0  Medium              1489.995000               427.850000
# 1058.0  High                 307.630000               307.630000
# 1067.0  Low                  828.685000               226.576000
# ...                                 ...                      ...
# 17498.0 Low                   14.060000                 3.520000
# 1038.0  Low                   23.335000                 2.815000
# 1048.0  Low                   26.876364                 2.704545
# 1297.0  Medium                16.400000                 2.410000
# 1037.0  High                   1.442500                 1.442500
#
# [82 rows x 2 columns]

# %%
"""Group by Priority and Status"""
# Average completion time by parent service
avgCmplPS = df_gb_avg(jemInc, ['PARENT_SERVICE', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_JEM/jemInc_avgCmplPS_pr_stat.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(jemInc, ['service', 'PRIORITY', 'STATUS'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_JEM/jemInc_avgCmplServ_pr_stat.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(jemInc, ['ASSIGNED_GROUP', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_JEM/jemInc_avgCmplAG_pr_stat.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(jemInc, ['org_id', 'PRIORITY', 'STATUS'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(jemInc, ['org_id', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_JEM/jemInc_avgCmplORG_pr_stat.csv")
avgBizORG.to_csv("./AVGDATA_JEM/jemInc_avgBizORG_pr_stat.csv")
# Out:
#                                                    ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                  PRIORITY STATUS
# Other Activities                High     CLOSED             10687.821000
#                                 Medium   RESOLVED            7805.560000
# High-performance Computing      Low      RESOLVED            3438.489167
# Intra-building Network Services Low      RESOLVED            2425.974000
# High-performance Computing      Low      INPROG              1911.870000
# ...                                                                  ...
# Midrange                        Low      SLAHOLD                     NaN
# Mobile Devices                  Medium   SLAHOLD                     NaN
# Other Activities                Low      AWAITCUS                    NaN
# Secure Remote Access            Medium   INPROG                      NaN
# Storage                         Low      QUEUED                      NaN
#
#                                                    BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                  PRIORITY STATUS
# Other Activities                High     CLOSED               10687.821000
#                                 Medium   RESOLVED              2248.700000
# High-performance Computing      Low      RESOLVED               983.534583
# Intra-building Network Services Low      RESOLVED               695.532000
# High-performance Computing      Low      INPROG                 529.600000
# ...                                                                    ...
# Midrange                        Low      SLAHOLD                       NaN
# Mobile Devices                  Medium   SLAHOLD                       NaN
# Other Activities                Low      AWAITCUS                      NaN
# Secure Remote Access            Medium   INPROG                        NaN
# Storage                         Low      QUEUED                        NaN
#
# [90 rows x 2 columns]
#                                                                       ACTUAL_COMPLETION_HRS  \
# service                                            PRIORITY STATUS
# Other - Service Management                         High     CLOSED             11245.040965
#                                                    Medium   RESOLVED            7805.560000
# IBN - GC LAN                                       Low      RESOLVED            6070.220000
# High-performance Computing                         Low      RESOLVED            3577.381739
# Mainframe - zOS & zLinux                           Medium   CLOSED              3347.024615
# ...                                                                                     ...
# Midrange                                           Low      SLAHOLD                     NaN
# Mobile - Enterprise Mobile Device Management (E... Medium   SLAHOLD                     NaN
# Other - Service Management                         Low      AWAITCUS                    NaN
# Secure Remote Access                               Medium   INPROG                      NaN
# Storage                                            Low      QUEUED                      NaN
#
#                                                                       BUSINESS_COMPLETION_HRS
# service                                            PRIORITY STATUS
# Other - Service Management                         High     CLOSED               11245.040965
#                                                    Medium   RESOLVED              2248.700000
# IBN - GC LAN                                       Low      RESOLVED              1748.210000
# High-performance Computing                         Low      RESOLVED              1022.646522
# Mainframe - zOS & zLinux                           Medium   CLOSED                 956.189231
# ...                                                                                       ...
# Midrange                                           Low      SLAHOLD                       NaN
# Mobile - Enterprise Mobile Device Management (E... Medium   SLAHOLD                       NaN
# Other - Service Management                         Low      AWAITCUS                      NaN
# Secure Remote Access                               Medium   INPROG                        NaN
# Storage                                            Low      QUEUED                        NaN
#
# [146 rows x 2 columns]
#                                   ACTUAL_COMPLETION_HRS  \
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED               255749.272
# ITS00329       Low      CLOSED                 8234.610
# SM000537       Medium   RESOLVED               7805.560
# NW000452       Low      RESOLVED               6070.220
# DC000168       Low      CLOSED                 6053.320
# ...                                                 ...
# NW000453       Low      QUEUED                      NaN
# NW000481       Low      INPROG                      NaN
#                         QUEUED                      NaN
# NW000490       Low      INPROG                      NaN
#                         QUEUED                      NaN
#
#                                   BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED              255749.272000
# ITS00329       Low      CLOSED                2360.126923
# SM000537       Medium   RESOLVED              2248.700000
# NW000452       Low      RESOLVED              1748.210000
# DC000168       Low      CLOSED                1733.680000
# ...                                                   ...
# NW000453       Low      QUEUED                        NaN
# NW000481       Low      INPROG                        NaN
#                         QUEUED                        NaN
# NW000490       Low      INPROG                        NaN
#                         QUEUED                        NaN
#
# [453 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            7805.560000              2248.700000
# 1083.0 Low      CLOSED              4922.660000              1427.775000
# 1062.0 Low      RESOLVED            3438.489167               983.534583
# 1342.0 Medium   RESOLVED            2274.060000               654.050000
#        Low      RESOLVED            2062.025000               593.325000
# ...                                         ...                      ...
#                 AWAITVEN                    NaN                      NaN
#                 INPROG                      NaN                      NaN
#                 SLAHOLD                     NaN                      NaN
#        Medium   AWAITVEN                    NaN                      NaN
# 1355.0 Low      AWAITCUS                    NaN                      NaN
#
# [109 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            7805.560000              2248.700000
# 1342.0 High     CLOSED              1878.969913              1878.969913
# 1083.0 Low      CLOSED              4922.660000              1427.775000
# 1062.0 Low      RESOLVED            3438.489167               983.534583
# 1342.0 Medium   RESOLVED            2274.060000               654.050000
# ...                                         ...                      ...
#        Low      AWAITVEN                    NaN                      NaN
#                 INPROG                      NaN                      NaN
#                 SLAHOLD                     NaN                      NaN
#        Medium   AWAITVEN                    NaN                      NaN
# 1355.0 Low      AWAITCUS                    NaN                      NaN
#
# [109 rows x 2 columns]

# %%
"""Excluding Event Management"""
# Filter for event management tickets
eemInc = incidents[incidents["EXTERNAL_SYSTEM"] != "EVENTMANAGEMENT"]

# Reset index
eemInc = jemInc.reset_index(drop=True)

# Filter Incident owner history for event management tickets
eemIOH = incOwnHist[incOwnHist["ticket_nmbr"].isin(jemInc["TICKET_NMBR"])]

# Reset index
eemIOH = jemIOH.reset_index(drop=True)

# Display
display(eemInc)
display(eemIOH)
# Out:
#       TICKET_NMBR                   PARENT_SERVICE  \
# 0      IN10028612                       Middleware
# 1      IN10028613                         Midrange
# 2      IN10028615       High-performance Computing
# 3      IN10028617                         Midrange
# 4      IN10028618                 Other Activities
# ...           ...                              ...
# 96960  IN10293537  Intra-building Network Services
# 96961  IN10293538                       Middleware
# 96962  IN10293540       High-performance Computing
# 96963  IN10293541                         Midrange
# 96964  IN10293552                        Mainframe
#
#                           service  org_id ASSIGNED_GROUP           OPEN_DATE  \
# 0                      Middleware  1342.0       DC000152  01APR2016:00:01:16
# 1         Midrange - Windows -X86  1342.0       NDS00032  01APR2016:00:35:21
# 2      High-performance Computing  1342.0       DC000133  01APR2016:02:57:00
# 3         Midrange - Windows -X86  1342.0       DC000115  01APR2016:06:21:10
# 4      Other - Service Management  1342.0       ESI00011  01APR2016:06:30:34
# ...                           ...     ...            ...                 ...
# 96960                IBN - GC LAN  1047.0       NW000405  30NOV2021:20:54:25
# 96961                  Middleware  1047.0       DC000152  30NOV2021:21:21:23
# 96962  High-performance Computing  1062.0       DC000132  30NOV2021:21:42:14
# 96963                    Midrange  1342.0       DC000209  30NOV2021:21:44:01
# 96964                   Mainframe  1047.0       DC000155  30NOV2021:23:38:56
#
#                CLOSE_DATE PRIORITY    STATUS  ACTUAL_COMPLETION_HRS  \
# 0      01APR2016:08:26:30      Low    CLOSED                   8.42
# 1      11APR2016:11:06:12      Low    CLOSED                 250.51
# 2      01APR2016:07:42:08      Low    CLOSED                   4.75
# 3      18APR2016:13:09:13   Medium    CLOSED                 414.80
# 4      17APR2016:19:40:25   Medium    CLOSED                 397.16
# ...                   ...      ...       ...                    ...
# 96960  10DEC2021:08:38:54   Medium  RESOLVED                 227.74
# 96961  03DEC2021:06:42:48      Low    CLOSED                  57.36
# 96962                 NaN      Low  AWAITVEN                    NaN
# 96963  01DEC2021:08:37:06      Low    CLOSED                  10.88
# 96964  01DEC2021:03:10:13   Medium    CLOSED                   3.52
#
#        BUSINESS_COMPLETION_HRS      AGING CLASS_STRUCTURE_ID  \
# 0                         1.43        NaN               2101
# 1                        64.10        NaN                 21
# 2                         0.70        NaN               3102
# 3                       116.15        NaN               2101
# 4                       110.00        NaN               2102
# ...                        ...        ...                ...
# 96960                    71.63        NaN               2103
# 96961                    20.00        NaN               2102
# 96962                      NaN  19.658366               2102
# 96963                     1.62        NaN                 21
# 96964                     0.00        NaN               8004
#
#                      class_structure CLASSIFICATION_ID    classification  \
# 0                IT Issue \ Hardware              2101    Hardware Issue
# 1                           IT Issue                21          IT Issue
# 2      IT Request \ Software Request              3102  Software Request
# 3                IT Issue \ Hardware              2101    Hardware Issue
# 4                IT Issue \ Software              2102    Software Issue
# ...                              ...               ...               ...
# 96960            IT Issue \ Networks              2103    Networks Issue
# 96961            IT Issue \ Software              2102    Software Issue
# 96962            IT Issue \ Software              2102    Software Issue
# 96963                       IT Issue                21          IT Issue
# 96964         IT Issue \ Application              2107       Application
#
#        EXTERNAL_SYSTEM  GLOBAL_TICKET_ID CLOSURE_CODE  LAST_MODIFIED_DATE
# 0      EVENTMANAGEMENT               NaN          OTH  12APR2016:05:30:11
# 1      EVENTMANAGEMENT               NaN          CIS  22APR2016:05:30:33
# 2      EVENTMANAGEMENT               NaN          OSD  12APR2016:05:30:10
# 3      EVENTMANAGEMENT               NaN          BSR  29APR2016:05:30:36
# 4      EVENTMANAGEMENT               NaN          INF  28APR2016:05:30:07
# ...                ...               ...          ...                 ...
# 96960  EVENTMANAGEMENT               NaN         RWOI  10DEC2021:08:38:54
# 96961  EVENTMANAGEMENT               NaN           RP  14DEC2021:05:30:16
# 96962  EVENTMANAGEMENT               NaN           RP  30NOV2021:21:51:26
# 96963  EVENTMANAGEMENT               NaN           RP  12DEC2021:05:30:09
# 96964  EVENTMANAGEMENT               NaN           RP  11DEC2021:05:30:26
#
# [96965 rows x 20 columns]
#        ticket_nmbr    STATUS assigned_group    PARENT_SERVICE  \
# 0       IN10028612    QUEUED       DC000152        Middleware
# 1       IN10028612  RESOLVED       DC000152        Middleware
# 2       IN10028612    CLOSED       DC000152        Middleware
# 3       IN10028613    QUEUED       NDS00032          Midrange
# 4       IN10028613  RESOLVED       NDS00032          Midrange
# ...            ...       ...            ...               ...
# 420311  IN10293541       NEW            NaN               NaN
# 420312  IN10293552    INPROG       SM000562  Other Activities
# 420313  IN10293552    QUEUED       SM000562  Other Activities
# 420314  IN10293552    INPROG       DC000155         Mainframe
# 420315  IN10293552  RESOLVED       DC000155         Mainframe
#
#                            service         CHANGE_DATE  \
# 0                       Middleware  01APR2016:00:03:12
# 1                       Middleware  01APR2016:08:26:30
# 2                       Middleware  12APR2016:05:30:11
# 3          Midrange - Windows -X86  01APR2016:01:04:45
# 4          Midrange - Windows -X86  11APR2016:11:06:12
# ...                            ...                 ...
# 420311                         NaN                 NaN
# 420312  Other - Service Management                 NaN
# 420313  Other - Service Management                 NaN
# 420314                   Mainframe                 NaN
# 420315                   Mainframe                 NaN
#
#         TIME_IN_STATUS_BY_OWNER_HRS
# 0                          8.383333
# 1                          0.000000
# 2                               NaN
# 3                         64.100000
# 4                          0.000000
# ...                             ...
# 420311                          NaN
# 420312                     0.000000
# 420313                          NaN
# 420314                          NaN
# 420315                     0.000000
#
# [420316 rows x 7 columns]

# %%
# Average time incidents spend in particular status
avgTimeStatus = df_gb_avg(eemIOH, ['STATUS'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeStatus.to_csv("./AVGDATA_EEM/eemIOH_avgTimeStatus.csv")

# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(eemIOH, ['assigned_group'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_EEM/eemIOH_avgTimeAG.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(eemIOH, ['PARENT_SERVICE'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA_EEM/eemIOH_avgTimePS.csv")

# Average time incidents spend by service
avgTimeAG = df_gb_avg(eemIOH, ['service'], ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_EEM/eemIOH_avgTimeServ.csv")
# Out:
#             TIME_IN_STATUS_BY_OWNER_HRS
# STATUS
# AWAITVEN                     167.117355
# PENDINGVEN                    88.863389
# SLAHOLD                       73.841899
# AWAITCHG                      66.540715
# AWAITCUS                      58.563833
# PENDINGREV                    48.973810
# PENDINGCHG                    40.213333
# PENDING                       32.912584
# PENDINGCUS                    23.423246
# INPROG                        19.373189
# QUEUED                        14.187864
# HISTEDIT                       2.377778
# RESOLVED                       0.086900
# NEW                            0.000000
# CLOSED                              NaN
#                 TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group
# ESI00052                        2772.372917
# ITS00352                        2502.758333
# DC000145                        1724.883333
# NW000469                        1639.416667
# ITS00329                        1422.923016
# ...                                     ...
# EDC00041                           0.000000
# NW000467                           0.000000
# DC000226                                NaN
# ITS00373                                NaN
# ITS00400                                NaN
#
# [322 rows x 1 columns]
#                                                TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE
# Bulk Print                                                     1724.883333
# Distributed Print                                               319.450000
# Classified Infrastructure                                       290.000000
# Firewall                                                         44.564273
# Managed Secure File Transfer                                     26.101613
# High-performance Computing                                       25.617979
# Email                                                            24.196342
# Database                                                         21.292119
# Internal Credential Management (ICM)                             18.915646
# Data Centre Facilities Management                                17.377486
# Intra-building Network Services                                  17.048038
# Other Activities                                                 16.137184
# Toll-free Voice                                                  15.808333
# Directory Services                                               13.674057
# Mainframe                                                        13.657765
# Storage                                                          12.792047
# Conferencing Services                                            10.826754
# Secure Remote Access                                             10.386211
# Midrange                                                          9.648952
# Workplace Technology Services                                     8.953232
# Fixed Line                                                        8.442157
# Mobile Devices                                                    8.393838
# GC WAN                                                            7.766380
# Contact Centre                                                    6.612602
# Government of Canada Managed Security Service                     5.700000
# Cloud Brokering                                                   5.403983
# Middleware                                                        4.175667
#                                                     TIME_IN_STATUS_BY_OWNER_HRS
# service
# Bulk Print                                                          1724.883333
# Mobile Devices                                                       638.362500
# Distributed Print                                                    319.450000
# Classified Infrastructure - GCSI - Hosting Envi...                   290.000000
# Mainframe - zOS & zLinux                                             251.863226
# Intra-building Network Services                                      122.159201
# Other - Security                                                      93.827952
# Firewall                                                              44.564273
# Other - Internal Services & Strategy                                  42.347312
# High-performance Computing                                            33.040201
# Midrange - Storage and Virtualization                                 27.085609
# Facilities - Data Centre Facilities Racking & S...                    26.369173
# Managed Secure File Transfer                                          26.101613
# GC WAN National                                                       25.908069
# IBN - Data Centre Network                                             25.182632
# Email                                                                 24.196342
# Mobile - Mobile Device - Government Cellular Se...                    21.650000
# Mobile - Voice & Data                                                 21.483333
# Database                                                              21.292119
# Other - Project Management & Delivery                                 19.691667
# Internal Credential Management (ICM)                                  18.915646
# Other - Data Centre                                                   18.649236
# Facilities - Data Centre Facilities Power & Space                     18.437624
# Data Centre Facilities Management                                     16.244011
# Toll-free Voice                                                       15.808333
# Midrange                                                              15.197849
# Other - Service Management                                            14.202895
# Directory Services                                                    13.674057
# Storage                                                               13.001626
# IBN - GC LAN                                                          12.861148
# Conferencing - Videoconferencing                                      10.826754
# IBN - GC Wi-Fi                                                        10.715846
# Secure Remote Access                                                  10.386211
# Fixed Line                                                            10.101282
# Workplace Technology Services                                          8.953232
# IBN - Cabling - Install and Material                                   8.389962
# Midrange - Windows -X86                                                7.568455
# Mainframe                                                              7.567126
# GC WAN                                                                 7.525620
# Contact Centre                                                         6.612602
# Mobile - Enterprise Mobile Device Management (E...                     6.592775
# HPC -Big Data Exchange                                                 6.222748
# Government of Canada Managed Security Service                          5.700000
# Cloud Brokering                                                        5.403983
# Other - Telecom & Network                                              5.368789
# Storage - File                                                         4.843750
# Middleware                                                             4.175667
# Fixed - VoIP                                                           3.050000
# HPC - Interaction & Visualization                                      2.996704

# %%
"""Group By Status"""
# Average time incidents spend with assigned group
avgTimeAG = df_gb_avg(eemIOH, ['assigned_group', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_EEM/eemIOH_avgTimeAGStatus.csv")

# Average time incidents spend by parent service
avgTimePS = df_gb_avg(eemIOH, ['PARENT_SERVICE', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimePS.to_csv("./AVGDATA_EEM/eemIOH_avgTimePSStatus.csv")

# Average time incidents spend by service
avgTimeAG = df_gb_avg(eemIOH, ['service', 'STATUS'],
                      ['TIME_IN_STATUS_BY_OWNER_HRS'], ['TIME_IN_STATUS_BY_OWNER_HRS'])

# Save to file
avgTimeAG.to_csv("./AVGDATA_EEM/eemIOH_avgTimeServStatus.csv")
# Out:
#                          TIME_IN_STATUS_BY_OWNER_HRS
# assigned_group STATUS
# DC000118       QUEUED                    5559.466667
# ITS00340       AWAITCUS                  5552.816667
# ESI00052       AWAITCUS                  5550.833333
# ITS00329       AWAITCUS                  5446.583333
#                QUEUED                    3490.685714
# ...                                              ...
# SM000562       CLOSED                            NaN
# SM000585       AWAITCUS                          NaN
#                CLOSED                            NaN
# SM000586       CLOSED                            NaN
# TIVMON         CLOSED                            NaN
#
# [1480 rows x 1 columns]
#                                               TIME_IN_STATUS_BY_OWNER_HRS
# PARENT_SERVICE                    STATUS
# Bulk Print                        QUEUED                      2111.008333
#                                   INPROG                       952.633333
# Secure Remote Access              AWAITCUS                     727.808333
# Data Centre Facilities Management PENDINGVEN                   584.444444
# Email                             AWAITCUS                     570.076667
# ...                                                                   ...
# Other Activities                  CLOSED                              NaN
# Secure Remote Access              AWAITCHG                            NaN
#                                   CLOSED                              NaN
# Storage                           CLOSED                              NaN
# Workplace Technology Services     CLOSED                              NaN
#
# [221 rows x 1 columns]
#                                         TIME_IN_STATUS_BY_OWNER_HRS
# service                       STATUS
# Bulk Print                    QUEUED                    2111.008333
# Other - Security              AWAITCUS                  1468.991667
# Mobile Devices                INPROG                    1321.333333
#                               QUEUED                    1010.000000
# Bulk Print                    INPROG                     952.633333
# ...                                                             ...
# Secure Remote Access          AWAITCHG                          NaN
#                               CLOSED                            NaN
# Storage                       CLOSED                            NaN
# Storage - File                CLOSED                            NaN
# Workplace Technology Services CLOSED                            NaN
#
# [365 rows x 1 columns]

# %%
# Average completion time by status
avgCmplStatus = df_gb_avg(eemInc, ['STATUS'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA_EEM/eemInc_avgCmplStatus.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(eemInc, ['PARENT_SERVICE'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_EEM/eemInc_avgCmplPS.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(eemInc, ['service'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_EEM/eemInc_avgCmplServ.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(eemInc, ['ASSIGNED_GROUP'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_EEM/eemInc_avgCmplAG.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(eemInc, ['org_id'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(eemInc, ['org_id'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_EEM/eemInc_avgCmplORG.csv")
avgBizORG.to_csv("./AVGDATA_EEM/eemInc_avgBizORG.csv")
# Out:
#           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS
# RESOLVED            2568.350213               737.081915
# INPROG               955.990000               264.800000
# CLOSED               122.551871                43.918936
# QUEUED                28.370000                14.370000
# AWAITVEN               4.216667                 0.292222
# AWAITCUS                    NaN                      NaN
# SLAHOLD                     NaN                      NaN
#                                                ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE
# Firewall                                                  334.168306
# Other Activities                                          311.433446
# High-performance Computing                                228.265096
# Email                                                     197.513241
# Internal Credential Management (ICM)                      173.175082
# Intra-building Network Services                           134.191680
# Database                                                  113.763271
# Workplace Technology Services                             108.331128
# Mainframe                                                 101.080406
# Data Centre Facilities Management                          91.339244
# Directory Services                                         90.410906
# Secure Remote Access                                       86.932541
# Midrange                                                   81.611362
# Cloud Brokering                                            79.867973
# Storage                                                    68.340549
# GC WAN                                                     67.074588
# Conferencing Services                                      63.394615
# Mobile Devices                                             61.308249
# Fixed Line                                                 54.435000
# Government of Canada Managed Security Service              39.071250
# Contact Centre                                             34.406223
# Managed Secure File Transfer                               28.863333
# Middleware                                                 24.697767
#
#                                                BUSINESS_COMPLETION_HRS
# PARENT_SERVICE
# Firewall                                                     94.297132
# Other Activities                                            187.417807
# High-performance Computing                                   66.235825
# Email                                                        55.943657
# Internal Credential Management (ICM)                         46.918033
# Intra-building Network Services                              36.432287
# Database                                                     32.698271
# Workplace Technology Services                                27.255668
# Mainframe                                                    27.666743
# Data Centre Facilities Management                            29.602430
# Directory Services                                           25.349151
# Secure Remote Access                                         25.147727
# Midrange                                                     21.926172
# Cloud Brokering                                              21.341081
# Storage                                                      18.728566
# GC WAN                                                       17.713403
# Conferencing Services                                         8.395385
# Mobile Devices                                               16.546647
# Fixed Line                                                   15.062500
# Government of Canada Managed Security Service                10.373750
# Contact Centre                                               14.412410
# Managed Secure File Transfer                                  2.188333
# Middleware                                                    5.743201
#                                                     ACTUAL_COMPLETION_HRS  \
# service
# Mainframe - zOS & zLinux                                      1969.112875
# Intra-building Network Services                               1303.024045
# Other - Security                                               494.226139
# Firewall                                                       334.168306
# Other - Service Management                                     320.901298
# High-performance Computing                                     314.712877
# Email                                                          197.513241
# Internal Credential Management (ICM)                           173.175082
# Other - Project Management & Delivery                          153.010000
# Other - Data Centre                                            150.314180
# Facilities - Data Centre Facilities Power & Space              149.952121
# -1                                                             136.348122
# Midrange - Storage and Virtualization                          134.839195
# Midrange                                                       131.429144
# Facilities - Data Centre Facilities Racking & S...             127.141373
# GC WAN National                                                119.599055
# Database                                                       113.763271
# IBN - GC LAN                                                   112.248359
# Workplace Technology Services                                  108.331128
# IBN - Data Centre Network                                      107.781324
# IBN - GC Wi-Fi                                                  96.388517
# Directory Services                                              90.410906
# Secure Remote Access                                            86.932541
# Other - Internal Services & Strategy                            85.344000
# Data Centre Facilities Management                               81.134301
# Cloud Brokering                                                 79.867973
# Storage - File                                                  72.604000
# Storage                                                         68.263730
# IBN - Cabling - Install and Material                            67.328571
# GC WAN                                                          66.462381
# Mainframe                                                       63.607337
# Conferencing - Videoconferencing                                63.394615
# Mobile - Enterprise Mobile Device Management (E...              61.308249
# Midrange - Windows -X86                                         60.197846
# Fixed Line                                                      54.435000
# Other - Telecom & Network                                       39.331509
# Government of Canada Managed Security Service                   39.071250
# Contact Centre                                                  34.406223
# Managed Secure File Transfer                                    28.863333
# HPC - Interaction & Visualization                               26.981813
# Middleware                                                      24.697767
# HPC -Big Data Exchange                                          22.190731
#
#                                                     BUSINESS_COMPLETION_HRS
# service
# Mainframe - zOS & zLinux                                         561.594500
# Intra-building Network Services                                  372.335909
# Other - Security                                                 140.868399
# Firewall                                                          94.297132
# Other - Service Management                                       206.286496
# High-performance Computing                                        90.003782
# Email                                                             55.943657
# Internal Credential Management (ICM)                              46.918033
# Other - Project Management & Delivery                             41.130000
# Other - Data Centre                                               43.555434
# Facilities - Data Centre Facilities Power & Space                 43.036970
# -1                                                                39.477918
# Midrange - Storage and Virtualization                             38.597241
# Midrange                                                          36.674984
# Facilities - Data Centre Facilities Racking & S...                37.932941
# GC WAN National                                                   34.144488
# Database                                                          32.698271
# IBN - GC LAN                                                      30.192191
# Workplace Technology Services                                     27.255668
# IBN - Data Centre Network                                         28.464136
# IBN - GC Wi-Fi                                                    25.317376
# Directory Services                                                25.349151
# Secure Remote Access                                              25.147727
# Other - Internal Services & Strategy                              26.532000
# Data Centre Facilities Management                                 27.252007
# Cloud Brokering                                                   21.341081
# Storage - File                                                    25.115000
# Storage                                                           18.613495
# IBN - Cabling - Install and Material                              21.670936
# GC WAN                                                            17.521888
# Mainframe                                                         16.956056
# Conferencing - Videoconferencing                                   8.395385
# Mobile - Enterprise Mobile Device Management (E...                16.546647
# Midrange - Windows -X86                                           15.583220
# Fixed Line                                                        15.062500
# Other - Telecom & Network                                         10.243501
# Government of Canada Managed Security Service                     10.373750
# Contact Centre                                                    14.412410
# Managed Secure File Transfer                                       2.188333
# HPC - Interaction & Visualization                                  7.636133
# Middleware                                                         5.743201
# HPC -Big Data Exchange                                             9.913141
#                 ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP
# ITS00329                   8234.61000              2360.126923
# DC000168                   6053.32000              1733.680000
# ITS00353                   5674.99375              1622.812500
# EDC00065                   4159.62000              1206.150000
# NW000490                   3564.91000              1025.910000
# ...                               ...                      ...
# EU000203                      0.42000                 0.420000
# NDS00039                      0.36000                 0.370000
# NW000457                      0.31000                 0.300000
# DC000166                      0.15000                 0.150000
# DC000226                          NaN                      NaN
#
# [231 rows x 2 columns]
#          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 1083.0             4922.660000              1427.775000
# 1213.0              794.244130               222.682174
# 1067.0              757.639091               206.811818
# 1017.0              672.730000               190.740000
# 877.0               406.147857               115.354643
# 1040.0              330.750000                94.657059
# 992.0               308.160000                86.514706
# 1123.0              265.573393                73.196786
# 15833.0             251.928750                67.688125
# 1068.0              229.989375                64.426875
# 1062.0              215.685952                62.591154
# 1205.0              200.220000                53.566000
# 1165.0              186.020345                49.902759
# 1055.0              153.855388                41.691240
# 1053.0              137.537000                34.014000
# 1342.0              134.775859                59.188507
# 1087.0              127.173333                36.495000
# 1028.0              121.623247                33.264143
# 1355.0              108.402078                29.181499
# 1037.0              103.555152                25.743485
# 1228.0              101.441667                20.924167
# 1058.0               98.275870                30.875217
# 910.0                96.018240                25.731360
# 835.0                92.680958                25.053533
# 1045.0               91.840132                23.270658
# 1272.0               85.365841                22.845619
# 942.0                83.517379                22.854075
# 1060.0               81.638333                24.283333
# 912.0                68.585000                13.726000
# 1050.0               60.090658                15.709671
# 1047.0               53.467610                14.938453
# 1063.0               53.436202                12.512019
# 1065.0               51.111062                14.032174
# 1042.0               50.962222                11.201667
# 1303.0               48.663571                14.432857
# 853.0                37.954000                 9.877455
# 1057.0               32.002200                 7.044200
# 1048.0               31.248333                 2.975000
# 1038.0               26.908889                 5.973333
# 1297.0               16.400000                 2.410000
# 17498.0              14.060000                 3.520000
#          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id
# 1083.0             4922.660000              1427.775000
# 1213.0              794.244130               222.682174
# 1067.0              757.639091               206.811818
# 1017.0              672.730000               190.740000
# 877.0               406.147857               115.354643
# 1040.0              330.750000                94.657059
# 992.0               308.160000                86.514706
# 1123.0              265.573393                73.196786
# 15833.0             251.928750                67.688125
# 1068.0              229.989375                64.426875
# 1062.0              215.685952                62.591154
# 1342.0              134.775859                59.188507
# 1205.0              200.220000                53.566000
# 1165.0              186.020345                49.902759
# 1055.0              153.855388                41.691240
# 1087.0              127.173333                36.495000
# 1053.0              137.537000                34.014000
# 1028.0              121.623247                33.264143
# 1058.0               98.275870                30.875217
# 1355.0              108.402078                29.181499
# 1037.0              103.555152                25.743485
# 910.0                96.018240                25.731360
# 835.0                92.680958                25.053533
# 1060.0               81.638333                24.283333
# 1045.0               91.840132                23.270658
# 942.0                83.517379                22.854075
# 1272.0               85.365841                22.845619
# 1228.0              101.441667                20.924167
# 1050.0               60.090658                15.709671
# 1047.0               53.467610                14.938453
# 1303.0               48.663571                14.432857
# 1065.0               51.111062                14.032174
# 912.0                68.585000                13.726000
# 1063.0               53.436202                12.512019
# 1042.0               50.962222                11.201667
# 853.0                37.954000                 9.877455
# 1057.0               32.002200                 7.044200
# 1038.0               26.908889                 5.973333
# 17498.0              14.060000                 3.520000
# 1048.0               31.248333                 2.975000
# 1297.0               16.400000                 2.410000

# %%
"""Group by Priority"""
# Average completion time by status
avgCmplStatus = df_gb_avg(eemInc, ['STATUS', 'PRIORITY'],
                          ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                          ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplStatus.to_csv("./AVGDATA_EEM/eemInc_avgCmplStatus_pr.csv")

# Average completion time by parent service
avgCmplPS = df_gb_avg(eemInc, ['PARENT_SERVICE', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_EEM/eemInc_avgCmplPS_pr.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(eemInc, ['service', 'PRIORITY'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_EEM/eemInc_avgCmplServ_pr.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(eemInc, ['ASSIGNED_GROUP', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_EEM/eemInc_avgCmplAG_pr.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(eemInc, ['org_id', 'PRIORITY'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(eemInc, ['org_id', 'PRIORITY'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_EEM/eemInc_avgCmplORG_pr.csv")
avgBizORG.to_csv("./AVGDATA_EEM/eemInc_avgBizORG_pr.csv")
# Out:
#                    ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# STATUS   PRIORITY
# RESOLVED Low                 3163.196333               905.492667
# INPROG   Low                 1911.870000               529.600000
# RESOLVED Medium              1518.621765               439.886471
# CLOSED   High                 837.543947               837.543947
#          Low                  122.606400                34.244421
#          Medium                64.994634                17.593648
# QUEUED   Low                   28.370000                14.370000
# AWAITVEN Medium                 8.396667                 0.000000
#          Low                    2.126667                 0.438333
# INPROG   Medium                 0.110000                 0.000000
# AWAITCUS Low                         NaN                      NaN
# QUEUED   Medium                      NaN                      NaN
# SLAHOLD  Low                         NaN                      NaN
#          Medium                      NaN                      NaN
#                                                         ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                                PRIORITY
# Other Activities                              High               10687.821000
# Firewall                                      Low                  369.845076
# Email                                         Low                  289.634545
# Other Activities                              Low                  250.155151
# High-performance Computing                    Low                  238.201001
# Mainframe                                     Low                  201.895585
# Internal Credential Management (ICM)          Low                  175.780169
# High-performance Computing                    High                 147.878621
# Data Centre Facilities Management             Low                  139.458621
# Intra-building Network Services               Low                  135.294067
#                                               Medium               133.753041
# Secure Remote Access                          Low                  125.884364
# High-performance Computing                    Medium               118.146835
# Database                                      Low                  114.982749
# Workplace Technology Services                 Low                  110.864448
# Midrange                                      Medium               106.629494
# Directory Services                            Low                   97.451126
# Firewall                                      Medium                96.692697
# Internal Credential Management (ICM)          Medium                96.325000
# Fixed Line                                    Low                   93.760000
# Secure Remote Access                          Medium                84.264608
# Data Centre Facilities Management             Medium                80.951856
# Cloud Brokering                               Low                   79.867973
# Midrange                                      Low                   79.711229
# Conferencing Services                         Medium                75.385000
# Storage                                       Low                   72.878330
# GC WAN                                        Low                   71.488268
# Storage                                       High                  68.556667
# Mainframe                                     Medium                62.013086
# Mobile Devices                                Low                   61.364405
# Conferencing Services                         Low                   61.214545
# Directory Services                            Medium                56.150606
# GC WAN                                        Medium                54.456997
#                                               High                  52.628687
# Other Activities                              Medium                49.240088
# Midrange                                      High                  45.621257
# Mobile Devices                                Medium                42.440000
# Intra-building Network Services               High                  41.252530
# Database                                      Medium                40.040000
# Government of Canada Managed Security Service Low                   39.071250
# Contact Centre                                High                  37.832407
#                                               Medium                36.542927
# Storage                                       Medium                35.556029
# Workplace Technology Services                 Medium                33.252727
# Contact Centre                                Low                   31.869437
# Middleware                                    Medium                29.132321
# Managed Secure File Transfer                  Low                   28.863333
# Data Centre Facilities Management             High                  25.893333
# Middleware                                    Low                   24.225310
# Email                                         High                  20.793333
# Fixed Line                                    High                  17.500000
# Directory Services                            High                  17.031000
# Email                                         Medium                17.017647
# Fixed Line                                    Medium                12.720000
# Firewall                                      High                  10.501364
# Middleware                                    High                   6.971326
# Database                                      High                   3.900000
# Mainframe                                     High                   1.740000
#
#                                                         BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                                PRIORITY
# Other Activities                              High                 10687.821000
# Firewall                                      Low                    104.116250
# Email                                         Low                     81.879860
# Other Activities                              Low                     77.155713
# High-performance Computing                    Low                     68.884260
# Mainframe                                     Low                     55.723755
# Internal Credential Management (ICM)          Low                     47.650000
# High-performance Computing                    High                   147.878621
# Data Centre Facilities Management             Low                     38.980805
# Intra-building Network Services               Low                     36.237798
#                                               Medium                  37.205445
# Secure Remote Access                          Low                     36.274909
# High-performance Computing                    Medium                  33.802113
# Database                                      Low                     33.094313
# Workplace Technology Services                 Low                     27.875951
# Midrange                                      Medium                  29.129305
# Directory Services                            Low                     27.324642
# Firewall                                      Medium                  27.631573
# Internal Credential Management (ICM)          Medium                  25.325000
# Fixed Line                                    Low                     20.465000
# Secure Remote Access                          Medium                  24.385592
# Data Centre Facilities Management             Medium                  22.438068
# Cloud Brokering                               Low                     21.341081
# Midrange                                      Low                     21.195178
# Conferencing Services                         Medium                   8.655000
# Storage                                       Low                     19.816965
# GC WAN                                        Low                     18.368521
# Storage                                       High                    68.556667
# Mainframe                                     Medium                  16.793076
# Mobile Devices                                Low                     16.595893
# Conferencing Services                         Low                      8.348182
# Directory Services                            Medium                  14.496061
# GC WAN                                        Medium                  14.504987
#                                               High                    52.628687
# Other Activities                              Medium                  13.377255
# Midrange                                      High                    45.621257
# Mobile Devices                                Medium                   0.000000
# Intra-building Network Services               High                    41.252530
# Database                                      Medium                   5.315000
# Government of Canada Managed Security Service Low                     10.373750
# Contact Centre                                High                    37.832407
#                                               Medium                   9.453171
# Storage                                       Medium                   6.473088
# Workplace Technology Services                 Medium                   8.872727
# Contact Centre                                Low                      8.370000
# Middleware                                    Medium                   6.842109
# Managed Secure File Transfer                  Low                      2.188333
# Data Centre Facilities Management             High                    25.893333
# Middleware                                    Low                      4.909792
# Email                                         High                    20.793333
# Fixed Line                                    High                    17.500000
# Directory Services                            High                    17.031000
# Email                                         Medium                   4.974602
# Fixed Line                                    Medium                   1.820000
# Firewall                                      High                    10.501364
# Middleware                                    High                     6.971326
# Database                                      High                     3.900000
# Mainframe                                     High                     1.740000
#                                             ACTUAL_COMPLETION_HRS  \
# service                           PRIORITY
# Other - Service Management        High               11245.040965
# Mainframe - zOS & zLinux          Medium              3347.024615
#                                   Low                 1701.756866
# Intra-building Network Services   Low                 1694.976369
# GC WAN National                   Medium              1394.360000
# ...                                                           ...
# HPC - Interaction & Visualization Medium                 3.627843
# Intra-building Network Services   High                   3.574118
# Mainframe                         High                   1.740000
# -1                                Medium                 1.185385
# Storage - File                    High                   0.420000
#
#                                             BUSINESS_COMPLETION_HRS
# service                           PRIORITY
# Other - Service Management        High                 11245.040965
# Mainframe - zOS & zLinux          Medium                 956.189231
#                                   Low                    485.031343
# Intra-building Network Services   Low                    483.808393
# GC WAN National                   Medium                 403.145000
# ...                                                             ...
# HPC - Interaction & Visualization Medium                   0.820196
# Intra-building Network Services   High                     3.574118
# Mainframe                         High                     1.740000
# -1                                Medium                   0.199231
# Storage - File                    High                     0.420000
#
# [103 rows x 2 columns]
#                          ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY
# EDC00031       High               255749.27200            255749.272000
# ITS00329       Low                  8234.61000              2360.126923
# DC000168       Low                  6053.32000              1733.680000
# ITS00353       Low                  5674.99375              1622.812500
# NW000490       Low                  5567.63000              1589.630000
# ...                                        ...                      ...
# EU000203       High                    0.42000                 0.420000
# NDS00039       Low                     0.36000                 0.370000
# NW000457       Low                     0.31000                 0.300000
# DC000166       Low                     0.15000                 0.150000
# DC000226       Low                         NaN                      NaN
#
# [399 rows x 2 columns]
#                  ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY
# 1083.0 Low                 4922.660000              1427.775000
# 1342.0 High                1878.969913              1878.969913
# 1123.0 Medium              1489.995000               427.850000
# 1067.0 Low                  828.685000               226.576000
# 1213.0 Low                  794.244130               222.682174
# ...                                ...                      ...
# 1047.0 High                  10.732409                10.732409
# 835.0  High                   8.170000                 8.170000
# 1057.0 Medium                 4.780000                 4.770000
# 1065.0 High                   4.593548                 4.593548
# 1037.0 High                   1.442500                 1.442500
#
# [82 rows x 2 columns]
#                   ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id  PRIORITY
# 1342.0  High                1878.969913              1878.969913
# 1083.0  Low                 4922.660000              1427.775000
# 1123.0  Medium              1489.995000               427.850000
# 1058.0  High                 307.630000               307.630000
# 1067.0  Low                  828.685000               226.576000
# ...                                 ...                      ...
# 17498.0 Low                   14.060000                 3.520000
# 1038.0  Low                   23.335000                 2.815000
# 1048.0  Low                   26.876364                 2.704545
# 1297.0  Medium                16.400000                 2.410000
# 1037.0  High                   1.442500                 1.442500
#
# [82 rows x 2 columns]

# %%
"""Group by Priority and Status"""
# Average completion time by parent service
avgCmplPS = df_gb_avg(eemInc, ['PARENT_SERVICE', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplPS.to_csv("./AVGDATA_EEM/eemInc_avgCmplPS_pr_stat.csv")

# Average completion time by service
avgCmplServ = df_gb_avg(eemInc, ['service', 'PRIORITY', 'STATUS'],
                        ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                        ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplServ.to_csv("./AVGDATA_EEM/eemInc_avgCmplServ_pr_stat.csv")

# Average completion time by assigned group
avgCmplAG = df_gb_avg(eemInc, ['ASSIGNED_GROUP', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['ACTUAL_COMPLETION_HRS'])

# Save to file
avgCmplAG.to_csv("./AVGDATA_EEM/eemInc_avgCmplAG_pr_stat.csv")

# Average completion time by org id
# Note that sorting by business hours is different, probably due to data input error
avgCmplORG = df_gb_avg(eemInc, ['org_id', 'PRIORITY', 'STATUS'],
                       ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                       ['ACTUAL_COMPLETION_HRS'])

avgBizORG = df_gb_avg(eemInc, ['org_id', 'PRIORITY', 'STATUS'],
                      ['ACTUAL_COMPLETION_HRS', 'BUSINESS_COMPLETION_HRS'],
                      ['BUSINESS_COMPLETION_HRS'])

# Save to file
avgCmplORG.to_csv("./AVGDATA_EEM/eemInc_avgCmplORG_pr_stat.csv")
avgBizORG.to_csv("./AVGDATA_EEM/eemInc_avgBizORG_pr_stat.csv")
# Out:
#                                                    ACTUAL_COMPLETION_HRS  \
# PARENT_SERVICE                  PRIORITY STATUS
# Other Activities                High     CLOSED             10687.821000
#                                 Medium   RESOLVED            7805.560000
# High-performance Computing      Low      RESOLVED            3438.489167
# Intra-building Network Services Low      RESOLVED            2425.974000
# High-performance Computing      Low      INPROG              1911.870000
# ...                                                                  ...
# Midrange                        Low      SLAHOLD                     NaN
# Mobile Devices                  Medium   SLAHOLD                     NaN
# Other Activities                Low      AWAITCUS                    NaN
# Secure Remote Access            Medium   INPROG                      NaN
# Storage                         Low      QUEUED                      NaN
#
#                                                    BUSINESS_COMPLETION_HRS
# PARENT_SERVICE                  PRIORITY STATUS
# Other Activities                High     CLOSED               10687.821000
#                                 Medium   RESOLVED              2248.700000
# High-performance Computing      Low      RESOLVED               983.534583
# Intra-building Network Services Low      RESOLVED               695.532000
# High-performance Computing      Low      INPROG                 529.600000
# ...                                                                    ...
# Midrange                        Low      SLAHOLD                       NaN
# Mobile Devices                  Medium   SLAHOLD                       NaN
# Other Activities                Low      AWAITCUS                      NaN
# Secure Remote Access            Medium   INPROG                        NaN
# Storage                         Low      QUEUED                        NaN
#
# [90 rows x 2 columns]
#                                                                       ACTUAL_COMPLETION_HRS  \
# service                                            PRIORITY STATUS
# Other - Service Management                         High     CLOSED             11245.040965
#                                                    Medium   RESOLVED            7805.560000
# IBN - GC LAN                                       Low      RESOLVED            6070.220000
# High-performance Computing                         Low      RESOLVED            3577.381739
# Mainframe - zOS & zLinux                           Medium   CLOSED              3347.024615
# ...                                                                                     ...
# Midrange                                           Low      SLAHOLD                     NaN
# Mobile - Enterprise Mobile Device Management (E... Medium   SLAHOLD                     NaN
# Other - Service Management                         Low      AWAITCUS                    NaN
# Secure Remote Access                               Medium   INPROG                      NaN
# Storage                                            Low      QUEUED                      NaN
#
#                                                                       BUSINESS_COMPLETION_HRS
# service                                            PRIORITY STATUS
# Other - Service Management                         High     CLOSED               11245.040965
#                                                    Medium   RESOLVED              2248.700000
# IBN - GC LAN                                       Low      RESOLVED              1748.210000
# High-performance Computing                         Low      RESOLVED              1022.646522
# Mainframe - zOS & zLinux                           Medium   CLOSED                 956.189231
# ...                                                                                       ...
# Midrange                                           Low      SLAHOLD                       NaN
# Mobile - Enterprise Mobile Device Management (E... Medium   SLAHOLD                       NaN
# Other - Service Management                         Low      AWAITCUS                      NaN
# Secure Remote Access                               Medium   INPROG                        NaN
# Storage                                            Low      QUEUED                        NaN
#
# [146 rows x 2 columns]
#                                   ACTUAL_COMPLETION_HRS  \
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED               255749.272
# ITS00329       Low      CLOSED                 8234.610
# SM000537       Medium   RESOLVED               7805.560
# NW000452       Low      RESOLVED               6070.220
# DC000168       Low      CLOSED                 6053.320
# ...                                                 ...
# NW000453       Low      QUEUED                      NaN
# NW000481       Low      INPROG                      NaN
#                         QUEUED                      NaN
# NW000490       Low      INPROG                      NaN
#                         QUEUED                      NaN
#
#                                   BUSINESS_COMPLETION_HRS
# ASSIGNED_GROUP PRIORITY STATUS
# EDC00031       High     CLOSED              255749.272000
# ITS00329       Low      CLOSED                2360.126923
# SM000537       Medium   RESOLVED              2248.700000
# NW000452       Low      RESOLVED              1748.210000
# DC000168       Low      CLOSED                1733.680000
# ...                                                   ...
# NW000453       Low      QUEUED                        NaN
# NW000481       Low      INPROG                        NaN
#                         QUEUED                        NaN
# NW000490       Low      INPROG                        NaN
#                         QUEUED                        NaN
#
# [453 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            7805.560000              2248.700000
# 1083.0 Low      CLOSED              4922.660000              1427.775000
# 1062.0 Low      RESOLVED            3438.489167               983.534583
# 1342.0 Medium   RESOLVED            2274.060000               654.050000
#        Low      RESOLVED            2062.025000               593.325000
# ...                                         ...                      ...
#                 AWAITVEN                    NaN                      NaN
#                 INPROG                      NaN                      NaN
#                 SLAHOLD                     NaN                      NaN
#        Medium   AWAITVEN                    NaN                      NaN
# 1355.0 Low      AWAITCUS                    NaN                      NaN
#
# [109 rows x 2 columns]
#                           ACTUAL_COMPLETION_HRS  BUSINESS_COMPLETION_HRS
# org_id PRIORITY STATUS
# 1055.0 Medium   RESOLVED            7805.560000              2248.700000
# 1342.0 High     CLOSED              1878.969913              1878.969913
# 1083.0 Low      CLOSED              4922.660000              1427.775000
# 1062.0 Low      RESOLVED            3438.489167               983.534583
# 1342.0 Medium   RESOLVED            2274.060000               654.050000
# ...                                         ...                      ...
#        Low      AWAITVEN                    NaN                      NaN
#                 INPROG                      NaN                      NaN
#                 SLAHOLD                     NaN                      NaN
#        Medium   AWAITVEN                    NaN                      NaN
# 1355.0 Low      AWAITCUS                    NaN                      NaN
#
# [109 rows x 2 columns]
